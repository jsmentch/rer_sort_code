# %% [markdown]
# # notebook to sort the rer stuff

# %%
import os
import random

# %% [markdown]
# ReadNet format:
#
# sub-X > ses-X > task > File name
#
# What is session here?
# I think it is grade + assessment period eg K-Fall, G1-Winter, G2-EOY
#
# RER format:
#
# *keep all filenames the same for RER and ReadNet so that we can map them back to the demographics and scores
#
# Task > Semester > Item name > File Name
#
# Except:
#
# - Letter Names in Isolation: LNI
# - Letter Names in Context: LNC (also random guess)
# - Letter Sounds in Isolation: LSI
# - Letter Sounds in Context: LSC (also a guess haha!)
# - Rapid Letter Naming: RAN
# - Rapid Object Naming: RAO
#
# These tasks will need the following structure because there should only be one larger audio file for the entire task: Task > Semester > File Name. We won’t need to include Item Name like the others since there should only be one item.
#
# *can delete directions files

# %%
# print some random example split filenames from folders by TIME
def print_examples(startdate,enddate,foldir):
    folders = []
    for folder in os.listdir(foldir):
        if folder.isdigit():
            if os.path.isdir(os.path.join(foldir, folder)):
                if startdate <= int(folder) <= enddate:
                    folders.append(folder)

    for folder in folders:
        files = os.listdir(os.path.join(foldir, folder))
        #if files:
        random_selections = random.sample(files, 4)
        
        for filename in random_selections:

            #filename = 'G0_F1_D2-PictureNaming(KF1)-EVO_0_0016_a_U_0-11_18_0_0009-7DAB98.wav'
            split_filename = filename.split('-')
            print(folder)
            print(split_filename)

        print()
        
        
def print_sub_task_item(startdate,enddate,foldir,subind,taskind,itemind,gradeind):
    folders = []
    for folder in os.listdir(foldir):
        if folder.isdigit():
            if os.path.isdir(os.path.join(foldir, folder)):
                if startdate <= int(folder) <= enddate:
                    folders.append(folder)

    for folder in folders:
        print(folder)
        files = os.listdir(os.path.join(foldir, folder))
        #if files:
        random_selections = random.sample(files, 4)
        
        sublist=[]
        tasklist=[]
        itemlist=[]
        gradelist=[]
        for filename in random_selections:

            #filename = 'G0_F1_D2-PictureNaming(KF1)-EVO_0_0016_a_U_0-11_18_0_0009-7DAB98.wav'
            split_filename = filename.split('-')
            
            sublist.append(split_filename[subind])
            task=split_filename[taskind].split('(')[0]
            task=task.split(':')[0]
            task=task.split('Task')[0]
            task=task.split('Practice')[0]
            task=task.split('K')[0]
            task=task.replace('.', '')
            tasklist.append(task)
            itemlist.append(split_filename[itemind])
            gradelist.append(split_filename[gradeind])
            #print(split_filename)
        
        print(f'sub: {sublist}')
        print(f'task: {tasklist}')
        print(f'item: {itemlist}')
        print(f'grade: {gradelist}')
        print()
        
        
        
def pipe_sub_task_item_grade(startdate,enddate,foldir,subind,taskind,itemind,gradeind):
    folders=[]
    sublist=[]
    tasklist=[]
    itemlist=[]
    gradelist=[]
    folderlist=[]
    filelist=[]
    pathlist=[]
    for folder in os.listdir(foldir):
        if folder.isdigit():
            if os.path.isdir(os.path.join(foldir, folder)):
                if startdate <= int(folder) <= enddate:
                    folders.append(folder)

    for folder in folders:
        print(f'parsing folder: {folder}')
        files = os.listdir(os.path.join(foldir, folder))
        for filename in files:
            filelist.append(filename)
            pathlist.append(os.path.join(foldir, folder, filename))
            folderlist.append(folder)
            #filename = 'G0_F1_D2-PictureNaming(KF1)-EVO_0_0016_a_U_0-11_18_0_0009-7DAB98.wav'
            split_filename = filename.split('-')
            
            sublist.append(split_filename[subind])
            task=split_filename[taskind].split('(')[0]
            task=task.split(':')[0]
            task=task.split('Task')[0]
            task=task.split('Practice')[0]
            task=task.split('K')[0]
            task=task.replace('.', '')
            tasklist.append(task)
            itemlist.append(split_filename[itemind])
            gradelist.append(split_filename[gradeind])
            #print(split_filename)
    print(f'-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-\ncollected {len(filelist)} items\n')
    print(f'unique tasks: {set(tasklist)}\n')
    print(f'unique grades: {set(gradelist)}\n')
    print(f'unique subs: {set(sublist)}\n')
    print(f'unique items: {set(itemlist)}\n')
    print(f'filenames: {filelist[:5]}\n')
    print(f'paths: {pathlist[:5]}\n')
    return(sublist,tasklist,itemlist,gradelist,folderlist,filelist,pathlist)
#         print(f'sub: {sublist}')
#         print(f'task: {tasklist}')
#         print(f'item: {itemlist}')
#         print(f'grade: {gradelist}')
#         print()

# %% [markdown]
# ## Fall 2018
# Fall 2018	October 24 - December 12

# %%
startdate=20181024
enddate=20181212
foldir='/om/tmp/jsmentch/rer/Scores/'
subind=-2
taskind=1
itemind=-3
gradeind=0
sublist,tasklist,itemlist,gradelist,folderlist,filelist,pathlist=pipe_sub_task_item_grade(startdate,enddate,foldir,subind,taskind,itemind,gradeind)

#print_examples(startdate,enddate,foldir)
#print_sub_task_item(startdate,enddate,foldir,subind,taskind,itemind,gradeind)
# Out:
# parsing folder: 20181126
# parsing folder: 20181025
# parsing folder: 20181207
# parsing folder: 20181206
# parsing folder: 20181115
# parsing folder: 20181203
# parsing folder: 20181026
# parsing folder: 20181128
# parsing folder: 20181129
# parsing folder: 20181205
# parsing folder: 20181211
# parsing folder: 20181106
# parsing folder: 20181109
# parsing folder: 20181024
# parsing folder: 20181029
# parsing folder: 20181210
# parsing folder: 20181116
# parsing folder: 20181108
# parsing folder: 20181107
# parsing folder: 20181030
# parsing folder: 20181102
# parsing folder: 20181127
# parsing folder: 20181212
# parsing folder: 20181204
# parsing folder: 20181105
# parsing folder: 20181101
# parsing folder: 20181130
# parsing folder: 20181114
# parsing folder: 20181113
# -~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-
# collected 20145 items
#
# unique tasks: {'SentenceRepetition', 'PairedAssociateLearning', 'LetterSounds', 'LetterNaming', 'Deletion', 'PictureNaming', 'DigitSpan', 'NonwordRepetition', 'Blending', 'Synonyms'}
#
# unique grades: {'G0_F1_D2', 'G0_Exp_D2', 'G0_F1_D1', 'G0_Exp_D1', 'G0_F1_D2_v2', 'G0_Exp_D1_V2', 'G0_F1_D1_v2'}
#
# unique subs: {'11_18_0_0229', '11_18_0_0195', '11_18_0_0072', '11_18_0_0107', '11_18_0_0106', '11_18_0_0101', '11_18_0_0007', '11_18_0_0152', '11_18_0_0132', '11_18_0_0044', '11_18_0_0042', '11_18_0_0131', '11_18_0_0065', '11_18_0_0100', '11_18_0_0021', '11_18_0_0159', '11_18_0_0160', '11_18_0_0052', '11_18_0_0032', '11_18_0_0049', '11_18_0_0194', '11_18_0_0108', '11_18_0_0063', '11_18_0_0087', '11_18_0_0045', '11_18_0_0133', '11_18_0_0196', '11_18_0_0185', '11_18_0_0121', '11_18_0_0035', '11_18_0_0209', '11_18_0_0088', '11_18_0_0014', '11_18_0_0174', '11_18_0_0135', '11_18_0_0034', '11_18_0_0085', '11_18_0_0076', '11_18_0_0058', '11_18_0_0036', '11_18_0_0031', '11_18_0_0223', '11_18_0_0144', '11_18_0_0070', '11_18_0_0050', '11_18_0_0219', '11_18_0_0224', '11_18_0_0113', '11_18_0_0059', '11_18_0_0097', '11_18_0_0150', '11_18_0_0186', '11_18_0_0016', '11_18_0_0208', '11_18_0_0103', '11_18_0_0204', '11_18_0_0040', '11_18_0_0216', '11_18_0_0086', '11_18_0_0232', '11_18_0_0127', '11_18_0_0227', '11_18_0_0019', '11_18_0_0207', '11_18_0_0096', '11_18_0_0225', '11_18_0_0182', '11_18_0_0073', '11_18_0_0179', '11_18_0_0167', '11_18_0_0090', '11_18_0_0071', '11_18_0_0080', '11_18_0_0168', '11_18_0_0169', '11_18_0_0215', '11_18_0_0056', '11_18_0_0057', '11_18_0_0218', '11_18_0_0055', '11_18_0_0010', '11_18_0_0099', '11_18_0_0157', '11_18_0_0077', '11_18_0_0092', '11_18_0_0190', '11_18_0_0158', '11_18_0_0098', '11_18_0_0047', '11_18_0_0012', '11_18_0_0221', '11_18_0_0231', '11_18_0_0130', '11_18_0_0142', '11_18_0_0018', '11_18_0_0212', '11_18_0_0126', '11_18_0_0067', '11_18_0_0220', '11_18_0_0213', '11_18_0_0164', '11_18_0_0217', '11_18_0_0039', '11_18_0_0165', '11_18_0_0189', '11_18_0_0175', '11_18_0_0170', '11_18_0_0137', '11_18_0_0117', '11_18_0_0104', '11_18_0_0181', '11_18_0_0200', '11_18_0_0191', '11_18_0_0138', '11_18_0_0033', '11_18_0_0112', '11_18_0_0054', '11_18_0_0053', '11_18_0_0004', '11_18_0_0154', '11_18_0_0183', '11_18_0_0015', '11_18_0_0177', '11_18_0_0145', '11_18_0_0122', '11_18_0_0210', '11_18_0_0110', '11_18_0_0171', '11_18_0_0023', '11_18_0_0003', '11_18_0_0176', '11_18_0_0134', '11_18_0_0125', '11_18_0_0024', '11_18_0_0066', '11_18_0_0046', '11_18_0_0062', '11_18_0_0026', '11_18_0_0089', '11_18_0_0078', '11_18_0_0005', '11_18_0_0162', '11_18_0_0068', '11_18_0_0109', '11_18_0_0211', '11_18_0_0094', '11_18_0_0029', '11_18_0_0038', '11_18_0_0081', '11_18_0_0022', '11_18_0_0214', '11_18_0_0060', '11_18_0_0226', '11_18_0_0228', '11_18_0_0079', '11_18_0_0199', '11_18_0_0148', '11_18_0_0156', '11_18_0_0120', '11_18_0_0084', '11_18_0_0139', '11_18_0_0001', '11_18_0_0129', '11_18_0_0141', '11_18_0_0111', '11_18_0_0184', '11_18_0_0149', '11_18_0_0233', '11_18_0_0163', '11_18_0_0205', '11_18_0_0114', '11_18_0_0143', '11_18_0_0147', '11_18_0_0166', '11_18_0_0203', '11_18_0_0082', '11_18_0_0187', '11_18_0_0011', '11_18_0_0128', '11_18_0_0069', '11_18_0_0161', '11_18_0_0151', '11_18_0_0155', '11_18_0_0074', '11_18_0_0020', '11_18_0_0095', '11_18_0_0006', '11_18_0_0048', '11_18_0_0193', '11_18_0_0197', '11_18_0_0188', '11_18_0_0075', '11_18_0_0030', '11_18_0_0105', '11_18_0_0064', '11_18_0_0017', '11_18_0_0119', '11_18_0_0202', '11_18_0_0043', '11_18_0_0136', '11_18_0_0025', '11_18_0_0102', '11_18_0_0028', '11_18_0_0192', '11_18_0_0116', '11_18_0_0153', '11_18_0_0009', '11_18_0_0146', '11_18_0_0123', '11_18_0_0027', '11_18_0_0037', '11_18_0_0041', '11_18_0_0234', '11_18_0_0180', '11_18_0_0002', '11_18_0_0008', '11_18_0_0083', '11_18_0_0230', '11_18_0_0201', '11_18_0_0206'}
#
# unique items: {'EVO_0_0041_a_U_0', 'BLE_0_S_0028_a_U', 'DEL_0_S_0012_b_U', 'SRT_0_S_0007_a_U', 'DG4_0_S_0003_a_U', 'DEL_0_S_0027_b_U', 'SRT_0_S_0004_a_U', 'SYN_0_S_0006_a_U', 'SRT_0_S_0001_a_U', 'DEL_0_S_0003_b_P', 'NWR_0_S_0007_a_U', 'NWR_0_S_0013_a_U', 'SYN_0_S_0004_a_U', 'BLE_0_S_0042_a_U', 'DG4_0_S_0004_a_U', 'DG4_0_S_0001_a_U', 'EVO_0_0039_a_U_0', 'SRT_0_S_0015_a_U', 'EVO_0_0006_a_U_0', 'EVO_0_0019_a_U_0', 'SRT_0_S_0002_a_P', 'DG4_0_S_0002_a_U', 'BLE_0_S_0008_a_U', 'SRT_0_S_0029_a_U', 'BLE_0_S_0007_a_U', 'EVO_0_0028_a_U_0', 'EVO_0_0001_a_P', 'DEL_0_S_0009_b_U', 'DEL_0_S_0006_b_U', 'PA3_0_Trial_0002', 'DEL_0_S_0003_a_D', 'EVO_0_0047_a_U_0', 'NWR_0_S_0018_a_U', 'EVO_0_0008_a_U_0', 'PA3_0_Trial_0001', 'PAL_0_S_0002_a_U_Mowgaif', 'BLE_0_S_0017_a_U', 'NWR_0_S_0017_a_U', 'NWR_0_S_0008_a_U', 'EVO_0_0003_a_U_0', 'EVO_0_0014_a_U_0', 'RAN_0_A_0001_P_v2', 'BLE_0_S_0002_a_P', 'DEL_0_S_0030_b_U', 'DEL_0_S_0016_b_U', 'RAN_lower_k', 'DEL_0_S_0008_b_U', 'BLE_0_S_0020_a_U', 'BLE_0_S_0012_a_U', 'BLE_0_S_0050_a_U', 'EVO_0_0016_a_U_0', 'SYN_0_S_0007_a_U', 'SYN_0_S_0022_a_U', 'SYN_0_S_0018_a_U', 'DEL_0_S_0014_b_U', 'RAN_Upper_W', 'EVO_0_0049_a_U_0', 'NWR_0_A_0001_a_P_v2', 'DG4_0_S_0006_a_U', 'EVO_0_0025_a_U_0', 'EVO_0_0027_a_U_0', 'DEL_0_S_0004_b_U', 'SRT_0_S_0014_a_U', 'NWR_0_A_0002_a_P', 'EVO_0_0001_b_P', 'SYN_0_S_0005_a_U', 'BLE_0_S_0027_a_U', 'SYN_0_S_0003_a_P', 'SRT_0_S_0001_a_P', 'SRT_0_S_0021_a_U', 'BLE_0_S_0002_a_U', 'NWR_0_S_0009_a_U', 'DG4_0_S_0005_a_U', 'PAL_0_S_0003_a_D', 'SRT_0_S_0009_a_U2', 'BLE_0_S_0003_a_P', 'NWR_0_S_0006_a_U', 'NWR_0_S_0002_a_U', 'EVO_0_0010_a_U_0', 'BLE_0_S_0033_a_U', 'NWR_0_S_0001_a_U', 'EVO_0_0033_a_U_0', 'SYN_0_S_0025_a_U', 'EVO_0_0004_a_U_0', 'EVO_0_0002_a_P', 'SRT_0_S_0043_a_U', 'NWR_0_S_0012_a_U', 'NWR_0_S_0016_a_U', 'DEL_0_S_0002_b_P', 'DEL_0_S_0011_b_U', 'EVO_0_0038_a_U_0', 'DEL_0_S_0026_b_U', 'SRT_0_S_0022_a_U', 'EVO_0_0040_a_U_0', 'SYN_0_S_0012_a_U', 'NWR_0_S_0024_a_U', 'SRT_0_S_0012_a_U', 'BLE_0_S_0018_a_U', 'BLE_0_S_0002_a_D', 'DEL_0_S_0002_a_D', 'SYN_0_S_0001_a_U', 'EVO_0_0018_a_U_0', 'PAL_0_S_0001_a_U_Teeg', 'SRT_0_S_0026_a_U', 'BLE_0_S_0015_a_U', 'LSC_0_A_0001_a_P', 'SYN_0_S_0010_a_U', 'BLE_0_S_0001_a_U', 'BLE_0_S_0003_a_D', 'PAL_0_S_0004_a_U_Turchan', 'PA3_0_Trial_0003', 'BLE_0_S_0023_a_U', 'DEL_0_S_0001_b_U', 'SRT_0_S_0027_a_U', 'SYN_0_S_0011_a_U', 'NWR_0_S_0003_a_U', 'SYN_0_S_0014_a_U'}
#
# filenames: ['G0_F1_D2_v2-PictureNaming-Items(KF1)-EVO_0_0006_a_U_0-11_18_0_0074-26B752.wav', 'G0_F1_D2_v2-PictureNaming-Practice(K)-EVO_0_0001_a_P-11_18_0_0082-CD664D.wav', 'G0_F1_D2_v2-PictureNaming-Items(KF1)-EVO_0_0039_a_U_0-11_18_0_0082-F06C2B.wav', 'G0_F1_D2_v2-Blending-Items(KF1)-BLE_0_S_0042_a_U-11_18_0_0165-B07683.wav', 'G0_F1_D2_v2-NonwordRepetition-Items(K)-NWR_0_S_0002_a_U-11_18_0_0071-FEF42C.wav']
#
# paths: ['/om/tmp/jsmentch/rer/Scores/20181126/G0_F1_D2_v2-PictureNaming-Items(KF1)-EVO_0_0006_a_U_0-11_18_0_0074-26B752.wav', '/om/tmp/jsmentch/rer/Scores/20181126/G0_F1_D2_v2-PictureNaming-Practice(K)-EVO_0_0001_a_P-11_18_0_0082-CD664D.wav', '/om/tmp/jsmentch/rer/Scores/20181126/G0_F1_D2_v2-PictureNaming-Items(KF1)-EVO_0_0039_a_U_0-11_18_0_0082-F06C2B.wav', '/om/tmp/jsmentch/rer/Scores/20181126/G0_F1_D2_v2-Blending-Items(KF1)-BLE_0_S_0042_a_U-11_18_0_0165-B07683.wav', '/om/tmp/jsmentch/rer/Scores/20181126/G0_F1_D2_v2-NonwordRepetition-Items(K)-NWR_0_S_0002_a_U-11_18_0_0071-FEF42C.wav']

# %% [markdown]
# ## Winter 2019
# February 19 - March 29

# %%
startdate=20190219
enddate=20190329
foldir='/om/tmp/jsmentch/rer/Scores/'
subind=-2
taskind=1
itemind=-3
gradeind=0
#print_examples(startdate,enddate,foldir)
#print_sub_task_item(startdate,enddate,foldir,subind,taskind,itemind,gradeind)
sublist,tasklist,itemlist,gradelist,folderlist,filelist,pathlist=pipe_sub_task_item_grade(startdate,enddate,foldir,subind,taskind,itemind,gradeind)
# Out:
# parsing folder: 20190311
# parsing folder: 20190226
# parsing folder: 20190321
# parsing folder: 20190219
# parsing folder: 20190307
# parsing folder: 20190306
# parsing folder: 20190319
# parsing folder: 20190326
# parsing folder: 20190304
# parsing folder: 20190227
# parsing folder: 20190222
# parsing folder: 20190220
# parsing folder: 20190325
# parsing folder: 20190228
# parsing folder: 20190313
# parsing folder: 20190221
# parsing folder: 20190320
# parsing folder: 20190328
# parsing folder: 20190318
# parsing folder: 20190225
# parsing folder: 20190315
# parsing folder: 20190305
# parsing folder: 20190312
# parsing folder: 20190314
# parsing folder: 20190327
# parsing folder: 20190322
# parsing folder: 20190308
# -~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-
# collected 37173 items
#
# unique tasks: {'NonwordReading', 'RapidNaming', 'LetterSoundsContext', 'SentenceRepetition', 'GrowthMindsetQuestion', 'Deletion', 'LetterSoundsIsolated', 'PictureNaming', 'DigitSpan', 'PairedAssocLearning', 'VisualAttention', 'NonwordRepetition', 'WordReading', 'Synonyms'}
#
# unique grades: {'2019_Sp_G0_Leon_Day1', '2019_Sp_DeKalb_Day2', '2019_Sp_G0_Leon_Day2', '2019_Sp_DeKalb_Day1'}
#
# unique subs: {'11_18_0_022', '11_18_0_0072', '11_18_0_008', '22_18_0_087', '11_18_0_0007', '22_18_0_199', '11_18_0_0152', '22_18_0_003', '22_18_0_041', '11_18_0_0021', '11_18_0_0052', '11_18_0_0131', '22_18_0_184', '22_18_0_121', '22_18_0_044', '11_18_0_0049', '22_18_0_103', '11_18_0_0063', '22_18_0_130', '22_18_0_082', '11_18_0_0014', '11_18_0_0135', '11_18_0_0034', '22_18_0_1', '11_18_0_0036', '11_18_0_0223', '22_18_0_161', '11_18_0_0144', '22_18_0_116', '22_18_0_083', '11_18_0_0219', '22_18_0_123', '11_18_0_0113', '11_18_0_0097', '11_18_0_0224', '22_18_0_149', '11_18_0_0103', '22_18_0_109', '11_18_0_018', '22_18_0_09', '11_18_0_0225', '22_18_0_078', '11_18_0_02', '22_18_0_026', '11_18_0_0168', '11_18_0_019', '22_18_0_006', '11_18_0_0157', '11_18_0_0010', '11_18_0_0055', '11_18_0_0077', '22_18_0_181', '11_18_0_0190', '11_18_0_0130', '11_18_0_0018', '11_18_0_0067', '11_18_0_0217', '22_18_0_157', '11_18_0_0175', '11_18_0_0165', '22_18_0_010', '11_18_0_0191', '11_18_0_0138', '22_18_0_061', '11_18_0_0033', '22_18_0_092', '22_18_0_085', '22_18_0_117', '22_18_0_158', 'test_stu', '11_18_0_0122', '22_18_0_007', '22_18_0_098', '22_18_0_055', '11_18_0_0023', '11_18_0_0176', '22_18_0_150', '11_18_0_0046', '11_18_0_0173', '22_18_0_034', '11_18_0_0089', '11_18_0_0078', '11_18_0_0162', '11_18_0_005', '22_18_0_171', '11_18_0_0022', '22_18_0_035', '11_18_0_0214', '22_18_0_066', '11_18_0_0226', '22_18_0_178', '22_18_0_047', '22_18_0_040', '22_18_0_163', '11_18_0_001', '22_18_0_031', '11_18_0_0178', '22_18_0_001', '22_18_0_08', '22_18_0_099', '22_18_0_065', '22_18_0_195', '11_18_0_0205', '11_18_0_0147', '22_18_0_10', '11_18_0_0203', '22_18_0_165', '11_18_0_0187', '11_18_0_0011', '22_18_0_180', '22_18_0_04', '22_18_0_141', '22_18_0_011', '22_18_0_072', '11_18_0_0193', '11_18_0_0105', '11_18_0_0075', '11_18_0_0064', '11_18_0_0119', '22_18_0_063', '11_18_0_0136', '11_18_0_01', '11_18_0_0025', '22_18_0_190', '22_18_0_108', '22_18_0_089', '11_18_0_010', '22_18_0_014', '22_18_0_176', '11_18_0_0180', '11_18_0_0206', '11_18_0_0107', '11_18_0_0044', '22_18_0_033', '22_18_0_136', '22_18_0_024', '11_18_0_0100', '11_18_0_020', '22_18_0_155', '11_18_0_0087', '11_18_0_003', '22_18_0_096', '11_18_0_002', '11_18_0_0174', '11_18_0_00', '11_18_0_0058', '22_18_0_088', '11_18_0_0050', '22_18_0_00', '11_18_0_0150', '22_18_0_139', '22_18_0_008', '22_18_0_112', '11_18_0_0208', '22_18_0_115', '22_18_0_051', '22_18_0_179', '11_18_0_0216', 'test_stud', '11_18_0_0086', '11_18_0_0232', '22_18_0_11', '22_18_0_193', '22_18_0_097', '22_18_0_175', '22_18_0_056', '11_18_0_0', '11_18_0_0198', '22_18_0_119', '22_18_0_189', '11_18_0_0056', '22_18_0_091', '22_18_0_101', '22_18_0_058', '11_18_0_0098', '11_18_0_0047', '11_18_0_0231', '11_18_0_0212', '22_18_0_077', '11_18_0_0213', '22_18_0_057', '22_18_0_12', '11_18_0_0189', '11_18_0_0104', '11_18_0_0181', '22_18_0_021', '22_18_0_067', '11_18_0_0054', '22_18_0_19', '22_18_0_017', '11_18_0_0154', '22_18_0_196', '11_18_0_0110', '11_18_0_0171', '11_18_0_0134', '11_18_0_0024', '22_18_0_113', '22_18_0_076', '22_18_0_079', '11_18_0_0026', '22_18_0_124', '11_18_0_0109', '11_18_0_0094', '11_18_0_016', '11_18_0_0079', '22_18_0_084', '22_18_0_004', '11_18_0_0156', '22_18_0_030', '11_18_0_0120', '22_18_0_106', '11_18_0_017', '11_18_0_0111', '22_18_0_094', '22_18_0_15', '11_18_0_009', '22_18_0_005', '22_18_0_2', '11_18_0_0233', '22_18_0_090', '22_18_0_198', '11_18_0_0166', '22_18_0_102', '22_18_0_143', '22_18_0_062', '11_18_0_0069', '22_18_0_172', '22_18_0_075', '11_18_0_0074', '22_18_0_156', '11_18_0_0006', '22_18_0_032', '22_18_0_168', '11_18_0_0030', '11_18_0_0043', '22_18_0_015', '11_18_0_0192', '11_18_0_0009', '11_18_0_0027', '22_18_0_131', '11_18_0_0002', '11_18_0_0083', '11_18_0_0230', '22_18_0_042', '11_18_0_0229', '22_18_0_159', '22_18_0_104', '11_18_0_0106', '11_18_0_021', '11_18_0_0101', '22_18_0_019', '11_18_0_0132', '22_18_0_200', '22_18_0_174', '11_18_0_0032', '11_18_0_0194', '11_18_0_0108', '22_18_0_127', '11_18_0_014', '22_18_0 ...
#
# unique items: {'DGS_0_0031_a_U_5_5842', 'NRE_0_loke', 'SRT_0_0053_a_U_storm', 'SYN_0_0040_a_U_warm', 'WRE_0_come', 'DEL_0_0021_b_U_flip', 'WRE_0_you', 'NRE_0_shup', 'WRE_0_because', 'EVO_0_0020_a_U_0_stapler', 'DGS_0_9005_a_P', 'LS1_0_9002_d_P', 'DEL_0_0003_b_U_goldfish', 'WRE_0_for', 'WRE_0_eight', 'DEL_0_9101_a_D_small', 'PA3_0_Trial_0003_feedback', 'NWR_0_0017_nafburkud', 'RAO_0_9003_a_D', 'SRT_0_0027_a_U_sister', 'WRE_0_both', 'SYN_0_0006_a_U_hop', 'DEL_0_0034_b_U_false', 'SRT_0_0040_a_U_baby', 'SYN_0_0043_a_U_jog', 'NRE_0_velt', 'DEL_0_0011_b_U_seat', 'WRE_0_is', 'PA3_0_Trial_0001_feedback', 'EVO_0_0036_a_U_0_sub', 'NWR_0_0025_duhpakuhtayf', 'NRE_0_vall', 'NRE_0_pate', 'NRE_0_fet', 'NWR_0_9003_a_P', 'NRE_0_sug', 'EVO_0_9002_b_P', 'DEL_0_0010_b_U_napkin', 'EVO_0_0017_a_U_0_curtains', 'DGS_0_0036_a_U_1_1379', 'NRE_0_bim', 'SRT_0_0035_a_U_andrea', 'LSC_0_9004_a_D', 'LS1_0_9002_a_P', 'WRE_0_inside', 'LS1_0_9002_e_P', 'NWR_0_9002_a_P', 'EVO_0_0050_a_U_helmet', 'WRE_0_boy', 'SRT_0_0041_a_U_forest', 'DEL_0_0031_b_U_need', 'WRE_0_show', 'WRE_0_help', 'NRE_0_ter', 'NWR_0_0016_kuhcheyvap', 'NRE_0_pilt', 'EVO_0_0047_a_U_0_parachute', 'NRE_0_lor', 'NRE_0_gat', 'DGS_0_0022_a_U_4_2759', 'NWR_0_0024_goomdachahytowb', 'SRT_0_0015_a_U_quiet', 'NRE_0_9004_a_P', 'NRE_0_9002_a_P', 'PAL_0_S_0002_a_U_Mowgaif', 'EVO_0_0011_a_U_0_hammer', 'EVO_0_0045_a_U_0_hammock', 'NWR_0_0009_mookbowf', 'EVO_0_0051_a_U_umbrella', 'NRE_0_spag', 'SYN_0_0002_a_U_shut', 'SYN_0_0042_a_U_angry', 'NWR_0_0015_vuhbowkeiv', 'NRE_0_fand', 'SRT_0_0003_a_U_birds', 'SRT_0_0007_a_U_pancakes', 'WRE_0_again', 'GMS_0_9001_a_D', 'RAN_lower_k', 'EVO_0_0025_a_U_0_camel', 'SYN_0_0044_a_U_beaut', 'DGS_0_0029_a_U_3_4837', 'SRT_0_0008_a_U_goal', 'WRE_0_from', 'EVO_0_0013_a_U_0_robe', 'SRT_0_9003_a_P', 'WRE_0_problem', 'WRE_0_thing', 'LS1_0_9002_c_P', 'EVO_0_0043_a_U_0_magnet', 'NWR_0_0003_moif', 'EVO_0_0009_a_U_0_piano', 'EVO_0_0018_a_U_0_chimney', 'SRT_0_0029_a_U_toy', 'SYN_0_0041_a_U_small', 'WRE_0_my', 'WRE_0_all', 'SRT_0_0016_a_U_uncle', 'NWR_0_0001_towb', 'DGS_0_0028_a_U_2_7528', 'SYN_0_0048_a_U_dad', 'VAT_0_9001_b_D', 'DEL_0_0013_b_U_more', 'WRE_0_other', 'VAT_0_9001_a_D', 'WRE_0_picture', 'WRE_0_there', 'RAO_0_9002_a_P', 'NRE_0_heg', 'NRE_0_9003_a_P', 'DEL_0_0017_b_U_bold', 'EVO_0_9003_a_P', 'NRE_0_han', 'EVO_0_0032_a_U_0_anchor', 'WRE_0_9002_a_D', 'EVO_0_0052_a_U_measuring', 'NRE_0_nold', 'WRE_0_was', 'SYN_0_0001_a_U_quick', 'SRT_0_0052_a_U_outside', 'DGS_0_0032_a_U_R_9274', 'SRT_0_0030_a_U_ridden', 'WRE_0_do', 'VAT_0_9001_c_D', 'WRE_0_with', 'SRT_0_9002_a_P', 'PAL_0_S_0003_a_D', 'WRE_0_one', 'RAO_0_0002_a_U_book', 'NRE_0_vo', 'SYN_0_9002_a_P', 'WRE_0_want', 'DEL_0_9003_a_P', 'SYN_0_9003_a_P', 'WRE_0_she', 'SRT_0_0022_a_U_willie', 'DEL_0_0006_b_U_motel', 'SYN_0_0045_a_U_lady', 'EVO_0_0023_a_U_0_parrot', 'DEL_0_9102_a_D_end', 'NRE_0_dif', 'NRE_0_chid', 'LSC_0_9002_a_P', 'NWR_0_0006_noimahyd', 'WRE_0_not', 'WRE_0_said', 'NRE_0_stig', 'NWR_0_0027_vahftombuhgoid', 'NWR_0_0018_vugoobuhcheen', 'NRE_0_nar', 'NWR_0_0013_voogfowboik', 'WRE_0_little', 'EVO_0_0015_a_U_0_zipper', 'EVO_0_0030_a_U_0_violin', 'DEL_0_0027_b_U_beef', 'SRT_0_0032_a_U_road', 'EVO_0_9002_a_P', 'WRE_0_9001_b_D', 'LS1_0_9002_b_P', 'WRE_0_to', 'WRE_0_and', 'SYN_0_0012_a_U_naughty', 'PA3_0_Trial_0002_feedback', 'LSC_0_9003_a_D', 'WRE_0_two', 'DEL_0_0036_b_U_plant', 'WRE_0_9002_a_P', 'PAL_0_S_0001_a_U_Teeg', 'NRE_0_mish', 'DEL_0_9004_a_P', 'EVO_0_0049_a_U_0_paddle', 'EVO_0_0034_a_U_0_stump', 'SYN_0_0003_a_U_street', 'PAL_0_S_0004_a_U_Turchan', 'NRE_0_rike', 'WRE_0_some', 'DEL_0_0005_b_U_bedroom', 'WRE_0_have', 'WRE_0_last', 'DEL_0_0018_b_U_school'}
#
# filenames: ["2019_Sp_DeKalb_Day2-WordReading(K-DeKalb-Spring'19)-WRE_0_one-22_18_0_079-DF0104.wav", "2019_Sp_G0_Leon_Day1-SentenceRepetition(K-Spring'19)-SRT_0_0052_a_U_outside-11_18_0_0026-E68951.wav", "2019_Sp_G0_Leon_Day1-Deletion:Practice(K-Spring'19)-DEL_0_9003_a_P-11_18_0_0220-0565AD.wav", "2019_Sp_G0_Leon_Day1-Deletion:Task(K-Spring'19)-DEL_0_0013_b_U_more-11_18_0_0217-25AE62.wav", "2019_Sp_G0_Leon_Day1-NonwordReading(K-Leon-Spring'19)-NRE_0_mish-11_18_0_0211-288429.wav"]
#
# paths: ["/om/tmp/jsmentch/rer/Scores/20190311/2019_Sp_DeKalb_Day2-WordReading(K-DeKalb-Spring'19)-WRE_0_one-22_18_0_079-DF0104.wav", "/om/tmp/jsmentch/rer/Scores/20190311/2019_Sp_G0_Leon_Day1-SentenceRepetition(K-Spring'19)-SRT_0_0052_a_U_outside-11_18_0_0026-E68951.wav", "/om/tmp/jsmentch/rer/Scores/20190311/2019_Sp_G0_Leon_Day1-Deletion:Practice(K-Spring'19)-DEL_0_9003_a_P-11_18_0_0220-0565AD.wav", "/om/tmp/jsmentch/rer/Scores/20190311/2019_Sp_G0_Leon_Day1-Deletion:Task(K-Spring'19)-DEL_0_0013_b_U_more-11_18_0_0217-25AE62.wav", "/om/tmp/jsmentch/rer/Scores/20190311/2019_Sp_G0_Leon_Day1-NonwordReading(K-Leon-Spring'19)-NRE_0_mish-11_18_0_0211-288429.wav"]

# %% [markdown]
# ## Fall 2019
# October 1 - December 18

# %%
startdate=20191001
enddate=20191218
foldir='/om/tmp/jsmentch/rer/Scores/'
subind=-2
taskind=2
itemind=-3
gradeind=1
#print_examples(startdate,enddate,foldir)
#print_sub_task_item(startdate,enddate,foldir,subind,taskind,itemind,gradeind)
sublist,tasklist,itemlist,gradelist,folderlist,filelist,pathlist=pipe_sub_task_item_grade(startdate,enddate,foldir,subind,taskind,itemind,gradeind)
# Out:
# parsing folder: 20191104
# parsing folder: 20191121
# parsing folder: 20191215
# parsing folder: 20191011
# parsing folder: 20191116
# parsing folder: 20191119
# parsing folder: 20191028
# parsing folder: 20191002
# parsing folder: 20191019
# parsing folder: 20191007
# parsing folder: 20191203
# parsing folder: 20191114
# parsing folder: 20191018
# parsing folder: 20191112
# parsing folder: 20191003
# parsing folder: 20191218
# parsing folder: 20191022
# parsing folder: 20191023
# parsing folder: 20191125
# parsing folder: 20191113
# parsing folder: 20191008
# parsing folder: 20191122
# parsing folder: 20191010
# parsing folder: 20191017
# parsing folder: 20191202
# parsing folder: 20191217
# parsing folder: 20191001
# parsing folder: 20191120
# parsing folder: 20191107
# parsing folder: 20191216
# parsing folder: 20191006
# parsing folder: 20191101
# parsing folder: 20191014
# parsing folder: 20191029
# parsing folder: 20191213
# parsing folder: 20191105

# %% [markdown]
# ## Winter Spring 2020
# February 10 - March 13

# %%
startdate=20200210
enddate=20200313
foldir='/om/tmp/jsmentch/rer/Scores/'
subind=-2
taskind=2
itemind=-3
gradeind=1
#print_examples(startdate,enddate,foldir)
print_sub_task_item(startdate,enddate,foldir,subind,taskind,itemind,gradeind)
# Out:
# 20200217
# sub: ['Year2Columbia5', 'Year2Columbia5', 'Year2Columb', 'Year2Columbia5']
# task: ['GrowthMindsetQuestion', 'SentenceRepetition', 'LetterSoundsContext', 'SentenceRepetition']
# item: ['GMS_9001_a_Mindset', 'SRT_0056_a_scared', 'LSC_9003_a_Directions2', 'SRT_0011_a_father']
# grade: ['Day1KForm3', 'Day1KForm3', 'Day1KForm3', 'Day1KForm3']
#
# 20200221
# sub: ['11_19_0_1119', '55_19_0_1128', '11_19_0_1120', '55_19_0_1066']
# task: ['WordReading', 'NonwordReading', 'Synonyms', 'WordReading']
# item: ['WRE_9001_p_the', 'NRE_0003_a_dif', 'SYN_0001_a_quick', 'WRE_0082_a_more']
# grade: ['Day2KForm1', 'Day1KForm1', 'Day2KForm2', 'Day2KForm2']
#
# 20200226
# sub: ['11_18_0_0073', '11_18_0_0086', '11_19_0_1150', '66_19_0_1105']
# task: ['SentenceRepetition', 'WordReadingDay11st', 'PictureNaming', 'WordReading']
# item: ['SRT_0100_a_rained', 'WRE_0094_a_hope', 'EVO_9002_a_Directions2', 'WRE_0038_a_before']
# grade: ['Day11st', 'Day11st', 'Day2KForm1', 'Day2KForm1']
#
# 20200311
# sub: ['11_18_0', '66_19_0_1231', '66_19_0_1069', '11_19_0_1200']
# task: ['NonwordRepetition', 'PictureNaming', 'WordReading', 'SentenceRepetition']
# item: ['NWR_0119_geemferbowvkervoog', 'EVO_0247_a_fountain', 'WRE_0038_a_before', 'SRT_0030_a_ridden']
# grade: ['Day21st', 'Day1KForm3', 'Day2KForm1', 'Day1KForm2']
#
# 20200220
# sub: ['11_19_0_1111', '11_19_0_1109', '11_19_0_1128', '55_19_0_1085']
# task: ['SentenceRepetition', 'PictureNaming', 'WordReading', 'Deletion']
# item: ['SRT_0084_a_dogs', 'EVO_9003_a_Practice1', 'WRE_0075_a_will', 'DEL_0060_b_gate']
# grade: ['Day1KForm1', 'Day2KForm1', 'Day2KForm2', 'Day1KForm1']
#
# 20200312
# sub: ['11_19_0_1067', '11_18_0_0017', '11_18_0_0044', '11_18_0_0034']
# task: ['RapidNaming', 'PictureNaming', 'Synonyms', 'WordReadingDay21st']
# item: ['RAO_9002_a_Practice', 'EVO_0049_a_paddle', 'SYN_0106_a_mitten', 'WRE_0041_a_different']
# grade: ['Day2KForm1', 'Day11st', 'Day11st', 'Day21st']
#
# 20200304
# sub: ['55_19_0_1234', '11_18_0_0204', '11_19_0_1012', '11_19_0_1028']
# task: ['NonwordReading', 'SentenceRepetition', 'NonwordRepetition', 'SentenceRepetition']
# item: ['NRE_0004_a_fand', 'SRT_0096_a_park', 'NWR_0085_moidheyf', 'SRT_0015_a_quiet']
# grade: ['Day1KForm3', 'Day11st', 'Day1KForm3', 'Day1KForm2']
#
# 20200210
# sub: ['11_18_0_0120', '11_18_0_0139', '55_19_0_1054', '55_19_0_1032']
# task: ['WordReadingDay11st', 'WordReading', 'NonwordReading', 'Synonyms']
# item: ['WRE_0094_a_hope', 'WRE_9001_p_the', 'NRE_0058_a_pud', 'SYN_0080_a_jet']
# grade: ['Day11st', 'Day11st', 'Day1KForm2', 'Day1KForm1']
#
# 20200219
# sub: ['11_19_0_1126', '55_19_0_1023', '66_19_0_1128', '33_0_19_1039']
# task: ['WordReading', 'WordReading', 'SentenceRepetition', 'NonwordReadingDay21st']
# item: ['WRE_0087_a_off', 'WRE_0005_a_both', 'SRT_0104_a_pencils', 'NRE_0094_a_sark']
# grade: ['Day2KForm3', 'Day2KForm3', 'Day11st', 'Day21st']
#
# 20200306
# sub: ['55_19_0_1220', '55_19_0_1182', '11_19_0_1019', '55_19_0_1222']
# task: ['PictureNaming', 'PictureNaming', 'DigitSpan', 'NonwordReading']
# item: ['EVO_0047_a_parachute', 'EVO_0256_a_rug', 'DGS_0029_a_3_4837', 'NRE_0003_a_dif']
# grade: ['Day1KForm3', 'Day1KForm3', 'Day2KForm2', 'Day1KForm3']
#
# 20200218
# sub: ['11_19_0_1125', '55_19_0_1002', '55_19_0_1069', '11_19_0_1125']
# task: ['Deletion', 'DigitSpan', 'PictureNaming', 'NonwordReading']
# item: ['DEL_0059_b_farmer', 'DGS_0032_a_R_9274', 'EVO_0261_a_sink', 'NRE_0054_a_dach']
# grade: ['Day1KForm1', 'Day2KForm2', 'Day1KForm3', 'Day1KForm1']
#
# 20200211
# sub: ['11_18_0_0125', '11_18_0_0150', '33_0_19_1055', '11_19_0_1007']
# task: ['NonwordRepetition', 'NonwordReadingDay21st', 'WordReadingDay11st', 'NonwordReading']
# item: ['NWR_0097_bowfgeechoib', 'NRE_0087_a_zint', 'WRE_0096_a_which', 'NRE_0045_a_ap']
# grade: ['Day21st', 'Day21st', 'Day11st', 'Day1KForm1']
#
# 20200213
# sub: ['55_19_0_1078', '55_19_0_1031', '55_19_0_1013', '55_19_0_1013']
# task: ['PictureNaming', 'NonwordRepetition', 'PictureNaming', 'RapidNaming']
# item: ['EVO_0247_a_fountain', 'NWR_0081_gowb', 'EVO_0271_a_waffle', 'RAO_0002_a_book']
# grade: ['Day1KForm3', 'Day1KForm3', 'Day2KForm1', 'Day2KForm1']
#
# 20200228
# sub: ['11_18_0_0198', '11_18_0_0233', '11_18_0_0092', '11_18_0_0195']
# task: ['SentenceRepetition', 'SentenceRepetition', 'NonwordReadingDay21st', 'WordReadingDay21st']
# item: ['SRT_0061_a_package', 'SRT_0102_a_finger', 'NRE_0092_a_flot', 'WRE_0042_a_does']
# grade: ['Day11st', 'Day11st', 'Day21st', 'Day21st']
#
# 20200303
# sub: ['11_19_0_', '11_18_0_0064', '11_18_0_0094', '11_18_0_0098']
# task: ['NonwordRepetition', 'RapidNaming', 'Synonyms', 'NonwordRepetition']
# item: ['NWR_0024_goomdachahytowb', 'RAO_0002_a_book', 'SYN_0100_a_starving', 'NWR_0096_kahymgowboov']
# grade: ['Day2KForm1', 'Day11st', 'Day11st', 'Day21st']
#
# 20200310
# sub: ['11_19_0_1086', '11_19_0_1202', '11_19_0_1071', '55_19_0_1226']
# task: ['WordReading', 'NonwordReading', 'WordReading', 'PictureNaming']
# item: ['WRE_0090_a_over', 'NRE_0004_a_fand', 'WRE_0085_a_his', 'EVO_0248_a_grasshopper']
# grade: ['Day2KForm3', 'Day1KForm2', 'Day2KForm3', 'Day1KForm3']
#
# 20200309
# sub: ['11_18_0_0026', '11_19_0_1088', '11_19_0_1232', '11_19_0_1076']
# task: ['NonwordReadingDay11st', 'NonwordRepetition', 'NonwordReading', 'NonwordReading']
# item: ['NRE_0079_a_shad', 'NWR_0016_kuhcheyvap', 'NRE_9002_p_zuk', 'NRE_0070_a_bime']
# grade: ['Day11st', 'Day1KForm3', 'Day1KForm1', 'Day1KForm3']
#
# 20200227
# sub: ['11_18_0_0197', '33_0_19_1002', '11_19_0_1181', '11_18_0_0210']
# task: ['PictureNaming', 'Deletion', 'PictureNaming', 'SentenceRepetition']
# item: ['EVO_0049_a_paddle', 'DEL_0027_b_Beef', 'EVO_0239_a_carrot', 'SRT_0102_a_finger']
# grade: ['Day11st', 'Day1KForm3', 'Day1KForm3', 'Day11st']
#
# 20200302
# sub: ['11_18_0_01', '11_18_0_0198', '11_18_0_0227', '11_18_0']
# task: ['NonwordRepetition', 'WordReadingDay21st', 'WordReadingDay21st', 'NonwordRepetition']
# item: ['NWR_0109_tuhneydvoocheeb', 'WRE_0035_a_after', 'WRE_0042_a_does', 'NWR_0119_geemferbowvkervoog']
# grade: ['Day21st', 'Day21st', 'Day21st', 'Day21st']
#
# 20200305
# sub: ['55_19_0_1099', '66_19_0_1180', '55_19_0_1217', '11_19_0_1027']
# task: ['SentenceRepetition', 'Deletion', 'PictureNaming', 'LetterNamingContextDirections2']
# item: ['SRT_0030_a_ridden', 'DEL_0017_b_Bold', 'EVO_0261_a_sink', 'LNC_9003_a_Directions2']
# grade: ['Day1KForm2', 'Day1KForm1', 'Day1KForm3', 'Day2KForm1']
#
# 20200212
# sub: ['11_18_0_0151', '33_0_19_1041', '11_18_0_0151', '55_19_0_1023']
# task: ['GrowthMindsetQuestion', 'WordReadingDay21st', 'WordReadingDay11st', 'NonwordRepetition']
# item: ['GMS_9001_a_Mindset', 'WRE_0110_a_laugh', 'WRE_0102_a_answer', 'NWR_0085_moidheyf']
# grade: ['Day11st', 'Day21st', 'Day11st', 'Day1KForm3']
#
# 20200313
# sub: ['11_19_0_1033', '11_18_0_0028', '11_18_0_0041', '11_18_0_0028']
# task: ['NonwordRepetition', 'WordReading', 'NonwordRepetition', 'NonwordReadingDay21st']
# item: ['NWR_0086_chohgfeem', 'WRE_9001_p_the', 'NWR_0018_vugoobuhcheen', 'NRE_0014_a_pate']
# grade: ['Day1KForm3', 'Day21st', 'Day21st', 'Day21st']
#
# 20200224
# sub: ['11_18_0_0058', '11_19_0_1095', '11_18_0_0186', '11_18_0_0189']
# task: ['SentenceRepetition', 'LetterNamingContext', 'PictureNaming', 'SentenceRepetition']
# item: ['SRT_0101_a_plant', 'LNC_9002_a_Practice1', 'EVO_0273_a_whistle', 'SRT_0061_a_package']
# grade: ['Day11st', 'Day2KForm1', 'Day11st', 'Day11st']
#
# 20200225
# sub: ['55_19_0_1109', '11_18_0_0225', '11_18_0_0229', '55_19_0_1092']
# task: ['WordReading', 'WordReadingDay21st', 'WordReadingDay21st', 'SentenceRepetition']
# item: ['WRE_0033_a_with', 'WRE_0035_a_after', 'WRE_0111_a_enough', 'SRT_0074_a_nervous']
# grade: ['Day2KForm2', 'Day21st', 'Day21st', 'Day1KForm1']
#
# 20200214
# sub: ['11_18_0_0149', '11_18_0_0170', '11_18_0_0163', '11_18_0_0149']
# task: ['NonwordRepetition', 'WordReadingDay11st', 'Synonyms', 'NonwordReadingDay21st']
# item: ['NWR_0018_vugoobuhcheen', 'WRE_0103_a_across', 'SYN_0106_a_mitten', 'NRE_0093_a_stad']
# grade: ['Day21st', 'Day11st', 'Day11st', 'Day21st']

# %% [markdown]
# ## Fall 2020
# December 2 - December 18

# %%
startdate=20201202
enddate=20201218
foldir='/om/tmp/jsmentch/rer/Scores/'
subind=-2
taskind=1
itemind=-3
gradeind=0
#print_examples(startdate,enddate,foldir)
print_sub_task_item(startdate,enddate,foldir,subind,taskind,itemind,gradeind)
# Out:
# 20201214
# sub: ['11_20_0_2099', '11_20_0_2099', '11_20_0_2046', '11_20_0_2108']
# task: ['NonwordReading', 'Synonyms', 'Synonyms', 'SentenceRepetition']
# item: ['NRE_0105_a_clud', 'SYN_0151_a_slender', 'SYN_0132_a_thief', 'SRT_0134_a_drinks']
#
# 20201217
# sub: ['11_20_0_2076', '11_20_0_2005', '11_20_0_2112', '11_20_0_2005']
# task: ['NonwordReading', 'NonwordReading', 'Synonyms', 'PictureNaming']
# item: ['NRE_33_chisp_12', 'NRE_12_nar_01', 'SYN_0149_a_gorgeous', 'EVO_17_paddle_012']
#
# 20201215
# sub: ['11_20_0_2140', '11_20_0_2259', '11_20_0_2051', '11_20_0_2119']
# task: ['Blending', 'WordReading', 'Synonyms', 'SentenceRepetition']
# item: ['BLE_0081_a_outside', 'WRE_0179_a_year', 'SYN_6_naughty_012', 'SRT_0112_a_jump']
#
# 20201209
# sub: ['11_20_0_2196', '11_20_0_2196', '11_20_0_2134', '11_20_0']
# task: ['Blending', 'Deletion', 'Blending', 'NonwordRepetition']
# item: ['BLE_0080_a_strawberry', 'DEL_0082_b_sandal', 'BLE_22_knife_0', 'NWR_0135_torbhowdoovmohk']
#
# 20201203
# sub: ['11_20_0_2017', '11_20_0_2067', '11_20_0_2017', '11_20_0_2017']
# task: ['WordReading', 'Synonyms', 'WordReading', 'WordReading']
# item: ['WRE_0159_a_should', 'SYN_0146_a_adorable', 'WRE_26_show_012', 'WRE_24_said_0']
#
# 20201208
# sub: ['11_20_0_2115', '11_20_0_2106', '11_20_0_2079', '11_20_0_2115']
# task: ['SentenceRepetition', 'Synonyms', 'WordReading', 'Blending']
# item: ['SRT_19_storm_0', 'SYN_0145_a_furious', 'WRE_110_laugh_1', 'BLE_0080_a_strawberry']
#
# 20201204
# sub: ['11_20_0_2020', '11_20_0_2153', '11_20_0_20', '11_20_0_2049']
# task: ['WordReading', 'Deletion', 'SentenceRepetition', 'WordReading']
# item: ['WRE_0176_a_what', 'DEL_0086_b_fort', 'SRT_0116_a_breakfast', 'WRE_0173_a_very']
#
# 20201207
# sub: ['11_2', 'Year2Atlanta5', '11_20_0_2097', '11_20_0_2069']
# task: ['NonwordRepetition', 'Blending', 'SentenceRepetition', 'WordReading']
# item: ['NWR_0137_voogpeymowbtuhfoib', 'BLE_17_cupcake_0', 'SRT_0141_a_rain', 'WRE_9001_b_D']
#
# 20201216
# sub: ['11_20_0_2006', '11_20_0_2177', '11_20_0_2218', '11_20_0_2218']
# task: ['WordReading', 'Synonyms', 'Deletion', 'SentenceRepetition']
# item: ['WRE_78_went_0', 'SYN_30_mom_0', 'DEL_10_beef_0L', 'SRT_0108_a_drivers']
#
# 20201210
# sub: ['11_20_0_2211', '11_20_0_22', '11_20_0_2041', '11_20_0_2017']
# task: ['WordReading', 'NonwordRepetition', 'WordReading', 'PictureNaming']
# item: ['WRE_39_believe_12', 'NWR_0133_cheygdoiteeg', 'WRE_0128_a_dog', 'EVO_0313_a_scarf']
#
# 20201202
# sub: ['11_20_0_2175', '11_20_0_2175', '11_20_0_2175', '11_20_0_2175']
# task: ['SentenceRepetition', 'SentenceRepetition', 'SentenceRepetition', 'SentenceRepetition']
# item: ['SRT_0113_a_family', 'SRT_0112_a_jump', 'SRT_0119_a_gardens', 'SRT_6_quiet_012L']
#
# 20201218
# sub: ['11_20_0_2245', '11_20_0_2205', '11_20_0_2116', '11_20_0_2245']
# task: ['Blending', 'WordReading', 'Deletion', 'Deletion']
# item: ['BLE_14_fly_0L', 'WRE_0167_a_thin', 'DEL_0024_b_Grow', 'DEL_0092_b_candle']
#
# 20201211
# sub: ['11_20_0_2213', '11_20_0_2150', '11_20_0_2027', '11_20_0_2198']
# task: ['WordReading', 'PictureNaming', 'NonwordReading', 'PictureNaming']
# item: ['WRE_9001_p_the', 'EVO_0299_a_towel', 'NRE_42_zadkin_2', 'EVO_0309_a_lobster']

# %% [markdown]
# ## Winter Spring 2021
# Jan 5 April 5

# %%
startdate=20210105
enddate=20210405
foldir='/om/tmp/jsmentch/rer/Scores/'
subind=-2
taskind=1
itemind=-3
gradeind=0
#print_examples(startdate,enddate,foldir)
print_sub_task_item(startdate,enddate,foldir,subind,taskind,itemind,gradeind)
# Out:
# 20210112
# sub: ['11_20_0_2302', '11_20_0_2302', '11_20_0_2302', '11_20_0_2302']
# task: ['WordReading', 'WordReading', 'WordReading', 'GrowthMindsetQuestion']
# item: ['WRE_0125_a_company', 'WRE_110_laugh_1', 'WRE_48_information_2', 'GMS_9001_a_Mindset']
# grade: ['VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1']
#
# 20210325
# sub: ['11_20_0_2528', '11_20_0_2570', '11_20_0_2', '11_20_0_2640']
# task: ['PictureNaming', 'WordReading', 'OralReadingFluency', 'PictureNaming']
# item: ['EVO_17_paddle_012', 'WRE_80_give_0', 'ORF_001_a_rabbits', 'EVO_9003_a_Practice1']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G1F1', 'VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1']
#
# 20210128
# sub: ['11_20_0_2348', '11_20_0_2348', '11_20_0_2307', '11_20_0_2340']
# task: ['Synonyms', 'SentenceRepetition', 'PictureNaming', 'PictureNaming']
# item: ['SYN_0146_a_adorable', 'SRT_9_willie_012L', 'EVO_0305_a_donkey', 'EVO_35_magnet_0']
# grade: ['VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G2F1']
#
# 20210105
# sub: ['11_20_0_2019', '11_20_0_2221', '11_20_0_2221', '11_20_0_2019']
# task: ['GrowthMindsetQuestion', 'Deletion', 'SentenceRepetition', 'SentenceRepetition']
# item: ['GMS_9001_a_Mindset', 'DEL_0086_b_fort', 'SRT_0107_a_classroom', 'SRT_6_quiet_012L']
# grade: ['VirtualFall2020Day1G1F1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1G1F1']
#
# 20210202
# sub: ['11_20_0_2369', '11_20_0_', '11_20_0_2405', '11_20_0_23']
# task: ['WordReading', 'NonwordRepetition', 'SentenceRepetition', 'SentenceRepetition']
# item: ['WRE_14_inside_01', 'NWR_0150_neygmuhgefdeeb', 'SRT_0134_a_drinks', 'SRT_0126_a_libraries']
# grade: ['VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1']
#
# 20210215
# sub: ['11_20_0_2461', '11_20_0_2459', '11_20_0_2459', '11_20_0_2461']
# task: ['PictureNaming', 'Synonyms', 'NonwordReading', 'PictureNaming']
# item: ['EVO_0299_a_towel', 'SYN_0149_a_gorgeous', 'NRE_33_chisp_12', 'EVO_0288_a_mailbox']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2KF1']
#
# 20210308
# sub: ['11_20_0_2512', '11_20_0_2531', '11_20_0_2541', '11_20_0_2569']
# task: ['DigitSpan', 'Deletion', 'WordReading', 'Synonyms']
# item: ['DGS_0_0032_a_U', 'DEL_0085_b_fall', 'WRE_0134_a_flight', 'SYN_62_silent_0']
# grade: ['VirtualSpring2021Day1G3F1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G1F1']
#
# 20210312
# sub: ['11_20_0_2596', '11_20_0_25', '11_20_0_2596', '11_20_0_2523']
# task: ['PictureNaming', 'SentenceRepetition', 'DigitSpan', 'PictureNaming']
# item: ['EVO_9003_b_Practice2', 'SRT_0126_a_libraries', 'DGS_0_0036_a_U', 'EVO_9003_b_Practice2']
# grade: ['VirtualSpring2021Day1G3F1', 'VirtualFall2020Day1G2F1', 'VirtualSpring2021Day1G3F1', 'VirtualFall2020Day2G1F1']
#
# 20210210
# sub: ['11_20_0_2390', '11_20_0_2454', '11_20_0_2381', '11_20_0_2390']
# task: ['PictureNaming', 'SentenceRepetition', 'Blending', 'WordReading']
# item: ['EVO_18_parachute_012', 'SRT_0108_a_drivers', 'BLE_14_fly_0L', 'WRE_78_went_0']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2G1F1']
#
# 20210223
# sub: ['11_20_0_2476', '11_20_0_2476', '11_19_0_1003', '11_1']
# task: ['Deletion', 'Deletion', 'WordReading', 'NonwordRepetition']
# item: ['DEL_0090_b_birthday', 'DEL_30_belt_0L', 'WRE_26_show_012', 'NWR_0137_voogpeymowbtuhfoib']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day1G1F1', 'VirtualFall2020Day1G1F1']
#
# 20210113
# sub: ['11_20_0_2294', '11_20_0_2294', '11_20_0_2282', '11_20_0_2294']
# task: ['PictureNaming', 'Synonyms', 'PictureNaming', 'PictureNaming']
# item: ['EVO_69_collar_1', 'SYN_62_silent_0', 'EVO_0293_a_pretzel', 'EVO_0319_a_wagon']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2G2F1']
#
# 20210119
# sub: ['11_20_0_2293', '11_20_0_2293', '11_20_0_2293', '11_20_0_2293']
# task: ['PictureNaming', 'Blending', 'Blending', 'Deletion']
# item: ['EVO_47_heel_0', 'BLE_0090_a_apple', 'BLE_36_desk_0', 'DEL_0028_b_Time']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1']
#
# 20210203
# sub: ['11_20_0_2418', '11_20_0_2038', '11_20_0_2418', '11_20_0_2418']
# task: ['Deletion', 'NonwordReading', 'SentenceRepetition', 'SentenceRepetition']
# item: ['DEL_10_beef_0L', 'NRE_0123_a_lum', 'SRT_0118_a_cook', 'SRT_0119_a_gardens']
# grade: ['VirtualFall2020Day1KF1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1KF1']
#
# 20210107
# sub: ['11_20_0_2282', '11_20_0_2282', '11_20_0_2282', '11_20_0_2282']
# task: ['SentenceRepetition', 'Deletion', 'Blending', 'Deletion']
# item: ['SRT_0112_a_jump', 'DEL_16_more_0', 'BLE_14_fly_0L', 'DEL_0087_b_brain']
# grade: ['VirtualFall2020Day1KF1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1KF1']
#
# 20210125
# sub: ['11_20_0_2305', '11_20_0_2305', '11_20_0_2335', '11_20_0_2310']
# task: ['Blending', 'Deletion', 'Synonyms', 'SentenceRepetition']
# item: ['BLE_0098_a_cake', 'DEL_0086_b_fort', 'SYN_0132_a_thief', 'SRT_0119_a_gardens']
# grade: ['VirtualFall2020Day1KF1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1KF1']
#
# 20210226
# sub: ['11_20_0_2479', '11_20_0_2481', '11_20_0_2479', '11_18_0_0010']
# task: ['WordReading', 'Blending', 'Synonyms', 'NonwordReading']
# item: ['WRE_0117_a_boat', 'BLE_0082_a_birthday', 'SYN_0132_a_thief', 'NRE_0120_a_hax']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G2F1']
#
# 20210301
# sub: ['11_20_0_2510', '11_20_0_2', '11_20_0_2514', '11_20_0_2495']
# task: ['PictureNaming', 'OralReadingFluency', 'NonwordReading', 'PictureNaming']
# item: ['EVO_9003_a_Practice1', 'ORF_002_a_olympic', 'NRE_9002_p_zuk', 'EVO_0311_a_ostrich']
# grade: ['VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1']
#
# 20210114
# sub: ['11_20_0_2299', '11_20_0_2299', '11_20_0_2299', '11_20_0_2299']
# task: ['PictureNaming', 'Synonyms', 'NonwordReading', 'Synonyms']
# item: ['EVO_0309_a_lobster', 'SYN_0141_a_correct', 'NRE_0108_a_fid', 'SYN_0140_a_every']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G1F1']
#
# 20210106
# sub: ['11_20_0_2', '11_20_0_2277', '11_20_0_2288', '11_20_0_2277']
# task: ['SentenceRepetition', 'Blending', 'SentenceRepetition', 'GrowthMindsetQuestion']
# item: ['SRT_0135_a_bestfriend', 'BLE_0095_a_saw', 'SRT_6_quiet_012L', 'GMS_9001_a_Mindset']
# grade: ['VirtualFall2020Day1G2F1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1G1F1', 'VirtualFall2020Day1KF1']
#
# 20210115
# sub: ['11_20_0_2302', '11_20_0_2293', '11_20_0_2010', '11_20_0_2297']
# task: ['PictureNaming', 'Deletion', 'NonwordReading', 'Deletion']
# item: ['EVO_0308_a_knitting', 'DEL_0085_b_fall', 'NRE_0123_a_lum', 'DEL_0092_b_candle']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2KF1']
#
# 20210324
# sub: ['11_20_0_2627', '11_20_0_', '11_20_0_2634', '11_20_0_2627']
# task: ['Blending', 'NonwordRepetition', 'Synonyms', 'SentenceRepetition']
# item: ['BLE_0086_a_piano', 'NWR_0136_noikteyvapheeb', 'SYN_62_silent_0', 'SRT_0113_a_family']
# grade: ['VirtualFall2020Day1KF1', 'VirtualFall2020Day1G1F1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day1KF1']
#
# 20210126
# sub: ['11_20_0_2336', '11_20_0_2304', '11_20_0_2336', '11_20_0_2335']
# task: ['Deletion', 'Synonyms', 'Deletion', 'PictureNaming']
# item: ['DEL_0096_b_brake', 'SYN_0132_a_thief', 'DEL_3_motel_0L', 'EVO_0291_a_paperclip']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2G2F1']
#
# 20210219
# sub: ['11_20_0_2366', '11_20_0_2366', '11_20_0_2366', '11_20_0_2366']
# task: ['WordReading', 'WordReading', 'WordReading', 'WordReading']
# item: ['WRE_5_both_012', 'WRE_24_said_0', 'WRE_0117_a_boat', 'WRE_0133_a_find']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G1F1']
#
# 20210222
# sub: ['11_20_0_2442', '11_20_0_2468', '11_20_0_2468', '11_20_0_2468']
# task: ['Synonyms', 'Synonyms', 'PictureNaming', 'NonwordReading']
# item: ['SYN_62_silent_0', 'SYN_0151_a_slender', 'EVO_17_paddle_012', 'NRE_36_sheb_2']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G2F1']
#
# 20210402
# sub: ['11_20_0_2462', '11_20_0_2462', '11_20_0_2462', '11_20_0_2462']
# task: ['Deletion', 'PictureNaming', 'Synonyms', 'Blending']
# item: ['DEL_0091_b_headache', 'EVO_0324_a_puzzle', 'SYN_30_mom_0', 'BLE_0099_a_soap']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1']
#
# 20210302
# sub: ['11_19_0_1003', '11_19_0_1006', '11_19_0_1002', '11_19_0_']
# task: ['Synonyms', 'WordReading', 'Synonyms', 'NonwordRepetition']
# item: ['SYN_0136_a_leap', 'WRE_0159_a_should', 'SYN_0132_a_thief', 'NWR_0136_noikteyvapheeb']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualFall2020Day1G1F1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day1G1F1']
#
# 20210127
# sub: ['11_20_0_2346', '11_20_0_23', '11_20_0_2315', '11_20_0_2346']
# task: ['WordReading', 'NonwordRepetition', 'WordReading', 'Synonyms']
# item: ['WRE_0142_a_imagine', 'NWR_10_kuhcheyvap_012', 'WRE_111_enough_1', 'SYN_0144_a_infant']
# grade: ['VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G1F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1']
#
# 20210318
# sub: ['11_20_0_2601', '11_20_0_2618', '11_20_0_2604', '11_20_0_2601']
# task: ['PictureNaming', 'SentenceRepetition', 'Synonyms', 'PictureNaming']
# item: ['EVO_17_paddle_012', 'SRT_0133_a_vase', 'SYN_0118_a_speedy', 'EVO_69_collar_1']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2G2F1']
#
# 20210204
# sub: ['11_20_0_2348', '11_20_0_2360', '11_20_0_2310', '11_20_0_2395']
# task: ['PictureNaming', 'Deletion', 'PictureNaming', 'Synonyms']
# item: ['EVO_0280_a_basket', 'DEL_0082_b_sandal', 'EVO_0335_a_kite', 'SYN_0152_a_tardy']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2G2F1']
#
# 20210401
# sub: ['11_20_0_2580', '11_20_0_2580', '11_20_0_2580', '11_20_0_2580']
# task: ['Synonyms', 'Synonyms', 'Synonyms', 'NonwordReading']
# item: ['SYN_62_silent_0', 'SYN_0136_a_leap', 'SYN_6_naughty_012', 'NRE_9003_p_vat']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G1F1']
#
# 20210323
# sub: ['11_20_0_2618', '11_19_0_1007', '11_20_0_2490', '11_20_0_2618']
# task: ['Synonyms', 'SentenceRepetition', 'DigitSpan', 'Synonyms']
# item: ['SYN_0150_a_gigantic', 'SRT_6_quiet_012L', 'DGS_0_0028_a_U', 'SYN_62_silent_0']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day1G1F1', 'VirtualSpring2021Day1G3F1', 'VirtualFall2020Day2G2F1']
#
# 20210225
# sub: ['11_20_0_2487', '11_20_0_2487', '11_20_0_2487', '11_20_0_2487']
# task: ['SentenceRepetition', 'SentenceRepetition', 'SentenceRepetition', 'SentenceRepetition']
# item: ['SRT_0111_a_excited', 'SRT_0115_a_notes', 'SRT_0107_a_classroom', 'SRT_0119_a_gardens']
# grade: ['VirtualFall2020Day1KF1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1KF1']
#
# 20210311
# sub: ['11_20_0_2353', '11_20_0_', '11_20_0_2536', '11_20_0_2']
# task: ['Blending', 'NonwordRepetition', 'SentenceRepetition', 'OralReadingFluency']
# item: ['BLE_0082_a_birthday', 'NWR_0136_noikteyvapheeb', 'SRT_0118_a_cook', 'ORF_001_a_rabbits']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day1G1F1', 'VirtualFall2020Day1G1F1', 'VirtualSpring2021Day1G3F1']
#
# 20210111
# sub: ['11_20_0_2254', '11_20_0_2254', '11_20_0_2254', '11_20_0_22']
# task: ['Deletion', 'PictureNaming', 'Deletion', 'SentenceRepetition']
# item: ['DEL_0097_b_slip', 'EVO_0334_a_bow', 'DEL_0091_b_headache', 'SRT_0121_a_newpencil']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day1G1F1']
#
# 20210209
# sub: ['11_20_0_2405', '11_20_0_2427', '11_20_0_2442', '11_20_0_2427']
# task: ['PictureNaming', 'PictureNaming', 'SentenceRepetition', 'Deletion']
# item: ['EVO_0321_a_wheelbarrow', 'EVO_35_magnet_0', 'SRT_9_willie_012L', 'DEL_0092_b_candle']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day2KF1']
#
# 20210329
# sub: ['11_20_0_2644', '11_20_0_2646', '11_18_0_0001', '11_20_0_2615']
# task: ['DigitSpan', 'Blending', 'SentenceRepetition', 'Blending']
# item: ['DGS_0_0032_a_U', 'BLE_0109_a_smell', 'SRT_0137_a_grandma', 'BLE_0111_a_small']
# grade: ['VirtualSpring2021Day1G3F1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day2KF1']
#
# 20210129
# sub: ['11_20_0_2272', '11_20_0_2309', '11_20_0_2315', '11_20_0_2315']
# task: ['WordReading', 'Deletion', 'NonwordReading', 'PictureNaming']
# item: ['WRE_26_show_012', 'DEL_16_more_0', 'NRE_93_stad_1', 'EVO_47_heel_0']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G2F1']
#
# 20210319
# sub: ['11_20_0_2529', '11_20_0_2593', '11_20_0_2593', '11_20_0_2529']
# task: ['NonwordReading', 'PictureNaming', 'Synonyms', 'PictureNaming']
# item: ['NRE_0123_a_lum', 'EVO_9003_b_Practice2', 'SYN_0120_a_terrible', 'EVO_13_chimney_012']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2G1F1']
#
# 20210310
# sub: ['11_20_0_2561', '11_20_0_2531', '11_20_0_2520', '11_20_0_2586']
# task: ['SentenceRepetition', 'Synonyms', 'PictureNaming', 'SentenceRepetition']
# item: ['SRT_0127_a_nurse', 'SYN_4_hop_0L', 'EVO_0308_a_knitting', 'SRT_0108_a_drivers']
# grade: ['VirtualFall2020Day1G1F1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day1KF1']
#
# 20210309
# sub: ['11_19_0_1006', '11_20_0_2538', '11_20_0_2', '11_20_0_2562']
# task: ['PictureNaming', 'DigitSpan', 'OralReadingFluency', 'DigitSpan']
# item: ['EVO_9003_b_Practice2', 'DGS_0_0032_a_U', 'ORF_001_a_rabbits', 'DGS_0_0032_a_U']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1']
#
# 20210326
# sub: ['11_20_0_2622', '11_20_0_260', '11_20_0_2623', '11_20_0_2623']
# task: ['WordReading', 'OralReadingFluency', 'DigitSpan', 'GrowthMindsetQuestion']
# item: ['WRE_0167_a_thin', 'ORF_004_a_tacos', 'DGS_0_0032_a_U', 'GMS_9001_a_Mindset']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1']
#
# 20210304
# sub: ['11_20_0_2498', '11_20_0_2498', '11_20_0_2507', '11_20_0_2353']
# task: ['GrowthMindsetQuestion', 'WordReading', 'NonwordReading', 'SentenceRepetition']
# item: ['GMS_9001_a_Mindset', 'WRE_0184_a_climate', 'NRE_9002_p_zuk', 'SRT_0109_a_horse']
# grade: ['VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1', 'VirtualFall2020Day1KF1']
#
# 20210322
# sub: ['11_20_0_2634', '11_20_0_2', '11_20_0_2584', '11_20_0']
# task: ['SentenceRepetition', 'NonwordRepetition', 'WordReading', 'NonwordRepetition']
# item: ['SRT_0110_a_teacher', 'NWR_0134_neygfohpevdak', 'WRE_0122_a_call', 'NWR_0135_torbhowdoovmohk']
# grade: ['VirtualFall2020Day1KF1', 'VirtualFall2020Day1G1F1', 'VirtualFall2020Day1G1F1', 'VirtualFall2020Day1G1F1']
#
# 20210122
# sub: ['11_20_0_2304', '11_20_0_2340', '11_20_0_2272', '11_20_0_2304']
# task: ['Synonyms', 'SentenceRepetition', 'Synonyms', 'Synonyms']
# item: ['SYN_52_applaud_2', 'SRT_0129_a_guitar', 'SYN_0134_a_beneath', 'SYN_0132_a_thief']
# grade: ['VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G1F1', 'VirtualFall2020Day1G2F1']
#
# 20210218
# sub: ['11_20_0_2460', '11_20_0_2477', '11_20_0_2477', '11_20_0_2460']
# task: ['PictureNaming', 'PictureNaming', 'NonwordReading', 'Blending']
# item: ['EVO_0326_a_dinosaur', 'EVO_8_camel_0L', 'NRE_0120_a_hax', 'BLE_0096_a_fan']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2KF1']
#
# 20210303
# sub: ['11_20_0_2493', '11_20_0_2502', '11_20_0_2', '11_20_0_2502']
# task: ['DigitSpan', 'PictureNaming', 'OralReadingFluency', 'DigitSpan']
# item: ['DGS_0_0031_a_U', 'EVO_9003_a_Practice1', 'ORF_001_a_rabbits', 'DGS_0_0036_a_U']
# grade: ['VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1']
#
# 20210330
# sub: ['11_20_0_2554', '11_20_0_2647', '11_20_0_2554', '11_20_0_2554']
# task: ['Synonyms', 'DigitSpan', 'Synonyms', 'Synonyms']
# item: ['SYN_62_silent_0', 'DGS_0_0022_a_U', 'SYN_0137_a_wonderful', 'SYN_0138_a_rapid']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualSpring2021Day1G3F1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G1F1']
#
# 20210108
# sub: ['11_20_0_2279', '11_20_0_2159', '11_20', '11_20_0_2289']
# task: ['WordReading', 'Blending', 'NonwordRepetition', 'Synonyms']
# item: ['WRE_0166_a_sword', 'BLE_0109_a_smell', 'NWR_12_goomdachahytowb_012', 'SYN_62_silent_0']
# grade: ['VirtualFall2020Day1G2F1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G1F1']
#
# 20210224
# sub: ['11_18_0_0007', '11_20_0_2332', '11_20_0_2332', '11_20_0_2486']
# task: ['SentenceRepetition', 'Blending', 'PictureNaming', 'Blending']
# item: ['SRT_0131_a_cats', 'BLE_14_fly_0L', 'EVO_9002_a_Directions2', 'BLE_0089_a_jacket']
# grade: ['VirtualFall2020Day1G2F1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day1KF1']
#
# 20210205
# sub: ['11_20_0_2354', '11_20_0_2373', '11_20_0_2412', '11_20_0_2373']
# task: ['Synonyms', 'Synonyms', 'Blending', 'Synonyms']
# item: ['SYN_0152_a_tardy', 'SYN_0145_a_furious', 'BLE_11_fish_0L', 'SYN_0147_a_exhausted']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day1G2F1']
#
# 20210316
# sub: ['11_20_0_2601', '11_20_0', '11_20_0_2', '11_20_0_2598']
# task: ['SentenceRepetition', 'NonwordRepetition', 'NonwordRepetition', 'Synonyms']
# item: ['SRT_33_package_012', 'NWR_11_vugoobuhcheen_012', 'NWR_0134_neygfohpevdak', 'SYN_62_silent_0']
# grade: ['VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G1F1', 'VirtualFall2020Day1G1F1']
#
# 20210317
# sub: ['11_20_0_2598', '11_20_0_2566', '11_20_0_2598', '11_20_0_2534']
# task: ['PictureNaming', 'PictureNaming', 'PictureNaming', 'PictureNaming']
# item: ['EVO_0282_a_cactus', 'EVO_9002_a_Directions2', 'EVO_0336_a_snail', 'EVO_47_heel_0']
# grade: ['VirtualFall2020Day2G1F1', 'VirtualSpring2021Day1G3F1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2KF1']
#
# 20210315
# sub: ['11_20_0_2541', '11_20_0_2541', '11_20_0_259', '11_20']
# task: ['PictureNaming', 'NonwordReading', 'SentenceRepetition', 'NonwordRepetition']
# item: ['EVO_9002_a_Directions2', 'NRE_0125_a_naspin', 'SRT_0132_a_swimming', 'NWR_12_goomdachahytowb_012']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1']
#
# 20210211
# sub: ['11_20_0_2454', '11_20_0_2454', '11_20_0_2454', '11_20_0_2454']
# task: ['Blending', 'PictureNaming', 'Synonyms', 'PictureNaming']
# item: ['BLE_0084_a_toothpaste', 'EVO_0288_a_mailbox', 'SYN_6_naughty_012', 'EVO_0337_a_shark']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day2KF1']
#
# 20210331
# sub: ['11_20_0_2106', '11_20_0_2635', '11_20_0_2106', '11_20_0_2106']
# task: ['Synonyms', 'Synonyms', 'PictureNaming', 'Synonyms']
# item: ['SYN_62_silent_0', 'SYN_6_naughty_012', 'EVO_9003_b_Practice2', 'SYN_0153_a_pleasant']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G2F1']
#
# 20210305
# sub: ['11_20_0_2526', '11_20_0_2517', '11_20_0_2525', '11_20_0_2527']
# task: ['SentenceRepetition', 'PictureNaming', 'DigitSpan', 'Synonyms']
# item: ['SRT_0127_a_nurse', 'EVO_9002_a_Directions2', 'DGS_0_0032_a_U', 'SYN_75_dad_01']
# grade: ['VirtualFall2020Day1G1F1', 'VirtualSpring2021Day1G3F1', 'VirtualSpring2021Day1G3F1', 'VirtualFall2020Day1G1F1']
#
# 20210217
# sub: ['11_20_0_2446', '11_20_0_2446', '11_20_0_2332', '11_20_0_2451']
# task: ['Synonyms', 'Synonyms', 'Deletion', 'Synonyms']
# item: ['SYN_1_quick_012', 'SYN_0153_a_pleasant', 'DEL_0089_b_plate', 'SYN_0132_a_thief']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day2G1F1']
#
# 20210212
# sub: ['11_20_0_2465', '11_20_0_2412', '11_20_0_2462', '11_20_0_2383']
# task: ['WordReading', 'PictureNaming', 'Blending', 'WordReading']
# item: ['WRE_39_believe_12', 'EVO_0327_a_popsicle', 'BLE_3_rabbit_0L', 'WRE_16_last_01']
# grade: ['VirtualFall2020Day1G2F1', 'VirtualFall2020Day2KF1', 'VirtualFall2020Day1KF1', 'VirtualFall2020Day2G1F1']
#
# 20210208
# sub: ['11_20_0_2423', '11_20_0_2369', '11_20_0_2426', '11_20_0_2426']
# task: ['PictureNaming', 'PictureNaming', 'WordReading', 'PictureNaming']
# item: ['EVO_0329_a_tiger', 'EVO_0319_a_wagon', 'WRE_0133_a_find', 'EVO_17_paddle_012']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day2G2F1', 'VirtualFall2020Day2G1F1', 'VirtualFall2020Day2G1F1']
#
# 20210201
# sub: ['11_20_0_2305', '11_20_0_2395', '11_20', '11_20_0_2426']
# task: ['Deletion', 'WordReading', 'NonwordRepetition', 'WordReading']
# item: ['DEL_7_seat_0L', 'WRE_0162_a_special', 'NWR_0151_hevkeegorbpuhtohf', 'WRE_0178_a_who']
# grade: ['VirtualFall2020Day2KF1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G1F1']
#
# 20210216
# sub: ['11_20_0_2411', '11_20', '11_20_0_239', '11_20_0_2477']
# task: ['PictureNaming', 'NonwordRepetition', 'SentenceRepetition', 'WordReading']
# item: ['EVO_69_collar_1', 'NWR_0151_hevkeegorbpuhtohf', 'SRT_0140_a_bookhelp', 'WRE_9001_p_the']
# grade: ['VirtualFall2020Day2G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1', 'VirtualFall2020Day1G2F1']

# %% [markdown]
# ## Fall 2021
# October 4 Dec 17

# %%
startdate=20211004
enddate=20211217
foldir='/om/tmp/jsmentch/rer/Scores/'
subind=-2
taskind=1
itemind=-3
gradeind=0
#print_examples(startdate,enddate,foldir)
print_sub_task_item(startdate,enddate,foldir,subind,taskind,itemind,gradeind)
# Out:
# 20211018
# sub: ['66_21_0_3195', '11_20_0_2263', '11_20_0_2593', '11_20_0_2153']
# task: ['PictureNaming', 'PictureNaming', 'Synonyms', 'PictureNaming']
# item: ['EVO_0295_a_snowman', 'EVO_0407_a_mummy', 'SYN_0179_a_saucer', 'EVO_0417_a_cuff']
# grade: ['VirtualFall2021Day1KF1', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day2G1F2']
#
# 20211112
# sub: ['11_21_0_3152', '66_19_0_1166', '11_21_0_3061', '11_21_0_314']
# task: ['SentenceRepetition', 'SentenceRepetition', 'Blending', 'SentenceRepetition']
# item: ['SRT_0129_a_guitar', 'SRT_0214_a_award', 'BLE_0094_a_bag', 'SRT_0207_a_readbook']
# grade: ['VirtualFall2021Day2G3F1', 'VirtualFall2021Day1G2F2', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2G3F1']
#
# 20211209
# sub: ['66_19_0_1198', '66_19_0_11', '11_21_0_3244', 'fcrr9013']
# task: ['SentenceRepetition', 'SentenceRepetition', 'Synonyms', 'Synonyms']
# item: ['SRT_0131_a_cats', 'SRT_0139_a_bluechair', 'SYN_0182_a_miserable', 'SYN_12_vanish_0']
# grade: ['VirtualFall2021Day1G2F2', 'VirtualFall2021Day1G2F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2']
#
# 20211207
# sub: ['11_20_0_2171', '55_21_0_3037', '66_21_0_3034', '11_21_0_3187']
# task: ['NonwordReading', 'PictureNaming', 'Synonyms', 'NonwordReading']
# item: ['NRE_9002_p_zuk', 'EVO_151_snorkel_3', 'SYN_0157_a_swift', 'NRE_9002_p_zuk']
# grade: ['VirtualFall2021Day2G2F2', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day2G2F2', 'VirtualFall2021Day2G2F2']
#
# 20211126
# sub: ['fcrr9026', 'fcrr9026', 'fcrr9028', 'fcrr9028']
# task: ['WordReading', 'SentenceRepetition', 'PictureNaming', 'PictureNaming']
# item: ['WRE_0244_a_shrimp', 'SRT_0233_a_neverboring', 'EVO_18_parachute_0123', 'EVO_47_heel_0123']
# grade: ['VirtualFall2021Day1G3F1', 'VirtualFall2021Day1G3F1', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day2G3F1']
#
# 20211121
# sub: ['fcrr9007', 'fcrr9007', 'fcrr9007', 'fcrr9007']
# task: ['PictureNaming', 'LetterNamingContext', 'PictureNaming', 'PictureNaming']
# item: ['EVO_17_paddle_012', 'RAN_Upper_W', 'EVO_0404_a_rake', 'EVO_13_chimney_012']
# grade: ['VirtualFall2021Day2KF1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2KF1']
#
# 20211014
# sub: ['11_20_0_2304', '11_20_0_220', '66_20_0_2071', '66_20_0_2050']
# task: ['PictureNaming', 'SentenceRepetition', 'RapidObjectNaming', 'DigitSpan']
# item: ['EVO_9003_a_Practice1', 'SRT_0140_a_bookhelp', 'RAO_0002_a_book', 'DGS_0_0028_a_U']
# grade: ['VirtualFall2021Day2G3F1', 'VirtualFall2021Day1G3F1', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2']
#
# 20211217
# sub: ['11_21_0_3242', '11_21_0_3242', '11_21_0_3242', '11_21_0_3242']
# task: ['Synonyms', 'Blending', 'PictureNaming', 'Synonyms']
# item: ['SYN_62_silent_01', 'BLE_0085_a_eyebrow', 'EVO_9003_a_Practice1', 'SYN_0171_a_evening']
# grade: ['VirtualFall2021Day2KF1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2KF1']
#
# 20211110
# sub: ['11_20_0_2147', '66_20_0_2065', 'Orego', '11_21_0_3154']
# task: ['Synonyms', 'GrowthMindsetQuestion', 'RapidObjectNamingDirections2Virtual', 'PictureNaming']
# item: ['SYN_0180_a_shove', 'GMS_9001_a_Mindset', 'RAO_9004_V_Directions3', 'EVO_9003_b_Practice2']
# grade: ['VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G3F1']
#
# 20211005
# sub: ['66_21_', '66_21_0_3066', '66_21_0_3139', '66_21_0_3140']
# task: ['RapidObjectNamingDirections2Virtual', 'Deletion', 'PictureNaming', 'PictureNaming']
# item: ['RAO_9005_V_Directions4', 'DEL_0101_b_money', 'EVO_0286_a_goose', 'EVO_0295_a_snowman']
# grade: ['VirtualFall2021Day1KF1', 'VirtualFall2021Day1KF1', 'VirtualFall2021Day1KF1', 'VirtualFall2021Day1KF1']
#
# 20211028
# sub: ['11_21_0_3000', '66_21_0_3029', '11_20_0_2131', '66_21_0_3028']
# task: ['SentenceRepetition', 'Synonyms', 'NonwordReading', 'WordReading']
# item: ['SRT_0182_a_bellrings', 'SYN_0148_a_finish', 'NRE_6_pate_012', 'WRE_9001_p_the']
# grade: ['VirtualFall2021Day1KF1', 'VirtualFall2021Day1G2F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G2F2']
#
# 20211015
# sub: ['11_20_0_2564', '11_20_0_2477', '11_20_0_2619', '11_20_0_2619']
# task: ['WordReading', 'WordReading', 'NonwordReading', 'Synonyms']
# item: ['WRE_0251_a_treasure', 'WRE_0144_a_join', 'NRE_0113_a_freb', 'SYN_0157_a_swift']
# grade: ['VirtualFall2021Day1G3F1', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day2G2F2', 'VirtualFall2021Day2G2F2']
#
# 20211004
# sub: ['66_21_0_3134', '66_21_', '66_21_0_3135', '66_21_0_3134']
# task: ['PictureNaming', 'RapidObjectNamingDirections2Virtual', 'PictureNaming', 'Deletion']
# item: ['EVO_17_paddle_012', 'RAO_9005_V_Directions4', 'EVO_0285_a_gloves', 'DEL_0110_b_ground']
# grade: ['VirtualFall2021Day1KF1', 'VirtualFall2021Day1KF1', 'VirtualFall2021Day1KF1', 'VirtualFall2021Day1KF1']
#
# 20211122
# sub: ['11_21_0_3176', '11_21_0_3031', '11_21_0_3031', '55_21_0_3024']
# task: ['SentenceRepetition', 'SentenceRepetition', 'GrowthMindsetQuestion', 'NonwordRepetition']
# item: ['SRT_33_package_012', 'SRT_0183_a_newalarm', 'GMS_9001_a_Mindset', 'NWR_0165_koovnorb']
# grade: ['VirtualFall2021Day2G3F1', 'VirtualFall2021Day1KF1', 'VirtualFall2021Day1KF1', 'Fall2021Day2G1F1']
#
# 20211214
# sub: ['11_21_0_3252', '11_21_0_3227', '11_21_0_3252', '11_21_0_3227']
# task: ['Synonyms', 'NonwordReading', 'Synonyms', 'NonwordReading']
# item: ['SYN_75_dad_01', 'NRE_0201_a_liffpawkit', 'SYN_0181_a_punch', 'NRE_0199_a_blextobe']
# grade: ['VirtualFall2021Day1G1F2', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day2G3F1']
#
# 20211123
# sub: ['11_20_0_2396', '11_21_0_3', '11_21_0_3187', 'fcrr9014']
# task: ['NonwordReading', 'SentenceRepetition', 'SentenceRepetition', 'PictureNaming']
# item: ['NRE_86_dasgif_123', 'SRT_0229_a_happydance', 'SRT_0129_a_guitar', 'EVO_0426_a_trunkelephant']
# grade: ['VirtualFall2021Day2G3F1', 'VirtualFall2021Day1G3F1', 'VirtualFall2021Day1G2F2', 'VirtualFall2021Day1G1F2']
#
# 20211026
# sub: ['66_20', '66_20_0_2106', '11_20_0_221', '66_20_0_2056']
# task: ['RapidObjectNamingDirections2Virtual', 'NonwordReading', 'SentenceRepetition', 'PictureNaming']
# item: ['RAO_9004_V_Directions3', 'NRE_0107_a_fep', 'SRT_0207_a_readbook', 'EVO_0409_a_mosquito']
# grade: ['VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day1G1F2']
#
# 20211208
# sub: ['fcrr90', 'fcrr9007', '11_21_', 'fcrr90']
# task: ['RapidObjectNamingDirections2Virtual', 'Blending', 'SentenceRepetition', 'RapidObjectNamingDirections2Virtual']
# item: ['RAO_9004_V_Directions3', 'BLE_36_desk_0', 'SRT_0226_a_soccerinstead', 'RAO_9005_V_Directions4']
# grade: ['VirtualFall2021Day1KF1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day1KF1']
#
# 20211022
# sub: ['11_21_0_3069', '11_20_0_2357', '11_21_0_3033', '11_20_0_2321']
# task: ['NonwordReading', 'WordReading', 'Blending', 'PictureNaming']
# item: ['NRE_9004_p_dit', 'WRE_9001_b_D', 'BLE_0107_a_black', 'EVO_0437_a_tile']
# grade: ['VirtualFall2021Day1G1F2', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2G1F2']
#
# 20211201
# sub: ['66_19_0_1070', '55_21_0_3033', '55_21_0_3033', '66_19_0_1026']
# task: ['Synonyms', 'PictureNaming', 'PictureNaming', 'Synonyms']
# item: ['SYN_62_silent_01', 'EVO_9002_a_Directions2', 'EVO_47_heel_0123', 'SYN_0186_a_shrub']
# grade: ['VirtualFall2021Day2G2F2', 'VirtualFall2021Day2G1F2', 'VirtualFall2021Day2G1F2', 'VirtualFall2021Day2G2F2']
#
# 20211021
# sub: ['11_20_', '11_20_0_', '11_21_0_3033', '11_20_0_2373']
# task: ['SentenceRepetition', 'SentenceRepetition', 'SentenceRepetition', 'NonwordReading']
# item: ['SRT_0226_a_soccerinstead', 'SRT_0233_a_neverboring', 'SRT_0184_a_orangecats', 'NRE_0185_a_plix']
# grade: ['VirtualFall2021Day1G3F1', 'VirtualFall2021Day1G3F1', 'VirtualFall2021Day1KF1', 'VirtualFall2021Day1G3F1']
#
# 20211104
# sub: ['11_20_0_2100', '11_20_0_2282', '66_21_0_3192', '11_20_0_210']
# task: ['WordReading', 'WordReading', 'LetterNamingContext', 'NonwordReading']
# item: ['WRE_0148_a_machine', 'WRE_16_last_01', 'RAN_Upper_W', 'NRE_0204_a_wunskerfleeg']
# grade: ['VirtualFall2021Day2G3F1', 'VirtualFall2021Day2G1F2', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2G3F1']
#
# 20211025
# sub: ['11_21_0_3048', '66_21_0_3191', '66_21_0_3131', '66_21_0_3196']
# task: ['NonwordReading', 'PictureNaming', 'LetterNamingContext', 'Synonyms']
# item: ['NRE_0107_a_fep', 'EVO_35_magnet_0123', 'RAN_Upper_W', 'SYN_79_jet_0']
# grade: ['VirtualFall2021Day1G1F2', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2KF1']
#
# 20211215
# sub: ['11_21_0_3238', '11_21_0_3229', '11_21_0_3245', '11_21_0_3238']
# task: ['NonwordReading', 'WordReading', 'Synonyms', 'WordReading']
# item: ['NRE_0192_a_glorstin', 'WRE_9001_b_D', 'SYN_0178_a_request', 'WRE_0244_a_shrimp']
# grade: ['VirtualFall2021Day1G3F1', 'VirtualFall2021Day1G2F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G3F1']
#
# 20211103
# sub: ['11_21_0_3161', '11_20_0_2561', '11_21_0_3122', '11_20_0_2561']
# task: ['SentenceRepetition', 'SentenceRepetition', 'SentenceRepetition', 'WordReading']
# item: ['SRT_0216_a_furry', 'SRT_0129_a_guitar', 'SRT_33_package_012', 'WRE_0222_a_moon']
# grade: ['VirtualFall2021Day1G2F2', 'VirtualFall2021Day1G2F2', 'VirtualFall2021Day1G2F2', 'VirtualFall2021Day1G2F2']
#
# 20211129
# sub: ['55_21_0_3026', '55_21_0_3032', '55_21_0_3025', '55_19_0_1065']
# task: ['SentenceRepetition', 'SentenceRepetition', 'NonwordRepetition', 'WordReading']
# item: ['SRT_0196_a_cattoy', 'SRT_0178_a_icecream', 'NWR_11_vugoobuhcheen_012', 'WRE_9001_b_D']
# grade: ['Fall2021Day2G1F1', 'Fall2021Day2G2F1', 'Fall2021Day1G1F1', 'Fall2021Day2G2F1']
#
# 20211210
# sub: ['66_19_0_1187', '66_19_0_1188', '66_19_0_1187', '66_21_0_3007']
# task: ['SentenceRepetition', 'Synonyms', 'SentenceRepetition', 'Synonyms']
# item: ['SRT_0215_a_squeaky', 'SYN_0161_a_prevent', 'SRT_0216_a_furry', 'SYN_75_dad_01']
# grade: ['VirtualFall2021Day1G2F2', 'VirtualFall2021Day2G2F2', 'VirtualFall2021Day1G2F2', 'VirtualFall2021Day2G2F2']
#
# 20211008
# sub: ['11_20_0_2159', '11_20_0_2619', 'Year2SantaRosa7', '11_20_0_2159']
# task: ['Synonyms', 'Synonyms', 'LetterNamingContextDirections2', 'Synonyms']
# item: ['SYN_73_sniff_1', 'SYN_75_dad_01', 'LNC_9003_a_Directions2', 'SYN_67_breezy_0']
# grade: ['VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G2F2', 'Fall2021Day2KF2', 'VirtualFall2021Day1G1F2']
#
# 20211115
# sub: ['11_20_0_2020', '66_20_0_2071', '11_20_0_2020', '11_21_0_3175']
# task: ['Synonyms', 'PictureNaming', 'SentenceRepetition', 'Synonyms']
# item: ['SYN_0153_a_pleasant', 'EVO_0380_a_shield', 'SRT_9_willie_012L', 'SYN_0160_a_mend']
# grade: ['VirtualFall2021Day1G2F2', 'VirtualFall2021Day2G1F2', 'VirtualFall2021Day1G2F2', 'VirtualFall2021Day2G2F2']
#
# 20211013
# sub: ['66_21_0_3067', '66_20_0_2034', '11_20_0_2170', '66_20_0_2034']
# task: ['Blending', 'PictureNaming', 'DigitSpan', 'DigitSpan']
# item: ['BLE_24_snake_0', 'EVO_9003_b_Practice2', 'DGS_0_0032_a_U', 'DGS_0_0031_a_U']
# grade: ['VirtualFall2021Day2KF1', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2']
#
# 20211119
# sub: ['55_19_0_106', '55_19_0_1066', '55_21_0_3017', '66_19_0_1172']
# task: ['NonwordRepetition', 'Synonyms', 'SentenceRepetition', 'Synonyms']
# item: ['NWR_0157_forbmuhteevheynohg', 'SYN_0146_a_adorable', 'SRT_0191_a_turtles', 'SYN_1_quick_012']
# grade: ['Fall2021Day1G2F1', 'Fall2021Day1G2F1', 'Fall2021Day2G1F1', 'VirtualFall2021Day2G2F2']
#
# 20211012
# sub: ['11_20_0_2115', '66_20_0_2079', '11_20_0_2115', '66_20_0_2069']
# task: ['DigitSpan', 'Synonyms', 'Synonyms', 'NonwordReading']
# item: ['DGS_0_0032_a_U', 'SYN_73_sniff_1', 'SYN_0131_a_blouse', 'NRE_0100_a_blep']
# grade: ['VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2']
#
# 20211027
# sub: ['66_21_0_3065', '11_20_0_2336', '11_21_0_3096', '11_21_0_3082']
# task: ['Synonyms', 'PictureNaming', 'DigitSpan', 'Synonyms']
# item: ['SYN_1_quick_012', 'EVO_0436_a_swan', 'DGS_0_0032_a_U', 'SYN_0168_a_purchase']
# grade: ['VirtualFall2021Day2KF1', 'VirtualFall2021Day2G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day2G2F2']
#
# 20211206
# sub: ['11_21_0_3195', '11_21_0_3195', '11_20_0_2340', '11_20_0_2340']
# task: ['WordReading', 'NonwordReading', 'WordReading', 'PictureNaming']
# item: ['WRE_9001_b_D', 'NRE_0196_a_blay', 'WRE_9001_p_the', 'EVO_9003_b_Practice2']
# grade: ['VirtualFall2021Day2G3F1', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day2G3F1']
#
# 20211202
# sub: ['55_21_0_3037', '11_20_0_2422', '66_20_0_2084', '66_20_0_2084']
# task: ['SentenceRepetition', 'PictureNaming', 'PictureNaming', 'NonwordReading']
# item: ['SRT_0231_a_sunstar', 'EVO_9003_b_Practice2', 'EVO_9003_b_Practice2', 'NRE_0111_a_flunt']
# grade: ['VirtualFall2021Day1G3F1', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2']
#
# 20211108
# sub: ['66_20_0_2109', '66_20_0_2109', '11_21_0_3142', '66_20_0_2109']
# task: ['Synonyms', 'NonwordReading', 'NonwordReading', 'PictureNaming']
# item: ['SYN_1_quick_012', 'NRE_9_fand_01', 'NRE_0189_a_agmest', 'EVO_0421_a_drill']
# grade: ['VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G3F1', 'VirtualFall2021Day1G1F2']
#
# 20211118
# sub: ['11_20_0_2626', '66_19_0_1195', '11_20_0_242', '11_21_0_3148']
# task: ['WordReading', 'Synonyms', 'SentenceRepetition', 'WordReading']
# item: ['WRE_0232_a_vehicle', 'SYN_0151_a_slender', 'SRT_0140_a_bookhelp', 'WRE_0137_a_great']
# grade: ['VirtualFall2021Day2G3F1', 'VirtualFall2021Day1G2F2', 'VirtualFall2021Day1G3F1', 'VirtualFall2021Day2G3F1']
#
# 20211020
# sub: ['11_20_0_2307', '11_20_0_2335', '66_21_0_3136', '66_21_0_3131']
# task: ['SentenceRepetition', 'PictureNaming', 'PictureNaming', 'SentenceRepetition']
# item: ['SRT_0129_a_guitar', 'EVO_9003_a_Practice1', 'EVO_0376_a_pirate', 'SRT_0188_a_return']
# grade: ['VirtualFall2021Day1G3F1', 'VirtualFall2021Day1G3F1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day1KF1']
#
# 20211101
# sub: ['11_21_0_3039', '66_21_0_3189', '11_21_0_3079', '66_21_0_3194']
# task: ['Synonyms', 'LetterNamingContext', 'Synonyms', 'PictureNaming']
# item: ['SYN_62_silent_01', 'LNC_9002_a_Practice1', 'SYN_0178_a_request', 'EVO_9002_a_Directions2']
# grade: ['VirtualFall2021Day2KF1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1KF1']
#
# 20211102
# sub: ['11_21_0_3127', '11_21_0_3110', '11_21_0_3110', '11_21_']
# task: ['Deletion', 'Synonyms', 'PictureNaming', 'RapidObjectNamingDirections2Virtual']
# item: ['DEL_0101_b_money', 'SYN_0168_a_purchase', 'EVO_9002_a_Directions2', 'RAO_9004_V_Directions3']
# grade: ['VirtualFall2021Day1KF1', 'VirtualFall2021Day2G2F2', 'VirtualFall2021Day2G2F2', 'VirtualFall2021Day1KF1']
#
# 20211011
# sub: ['66_21_0_3062', '66_21_', '66_21_0_3115', '66_21_0_3062']
# task: ['Deletion', 'RapidObjectNamingDirections2Virtual', 'Deletion', 'Deletion']
# item: ['DEL_0099_b_popcorn', 'RAO_9004_V_Directions3', 'DEL_0102_b_summer', 'DEL_10_beef_0L']
# grade: ['VirtualFall2021Day1KF1', 'VirtualFall2021Day1KF1', 'VirtualFall2021Day1KF1', 'VirtualFall2021Day1KF1']
#
# 20211130
# sub: ['11_21_0_32', '55_19_0_1066', '55_19_0_1066', '55_21_0_3031']
# task: ['SentenceRepetition', 'SentenceRepetition', 'WordReading', 'SentenceRepetition']
# item: ['SRT_0126_a_libraries', 'SRT_0167_a_squirrel', 'WRE_9001_p_the', 'SRT_0172_a_playball']
# grade: ['VirtualFall2021Day1G3F1', 'Fall2021Day2G2F1', 'Fall2021Day2G2F1', 'Fall2021Day2G2F1']
#
# 20211117
# sub: ['11_21_0_3149', '55_21_0_3007', 'fcrr9005', '66_20_0_2004']
# task: ['PictureNaming', 'DigitSpan', 'SentenceRepetition', 'SentenceRepetition']
# item: ['EVO_35_magnet_0123', 'DGS_R_9274_0', 'SRT_0184_a_orangecats', 'SRT_29_visit_1']
# grade: ['VirtualFall2021Day1G1F2', 'Fall2021Day1KF2', 'VirtualFall2021Day1KF1', 'VirtualFall2021Day1G2F2']
#
# 20211007
# sub: ['11_20_', '11_20_0_2586', '11_20_0_2468', '11_20_0_2468']
# task: ['SentenceRepetition', 'Synonyms', 'SentenceRepetition', 'NonwordReading']
# item: ['SRT_0226_a_soccerinstead', 'SYN_0131_a_blouse', 'SRT_0129_a_guitar', 'NRE_9002_p_zuk']
# grade: ['VirtualFall2021Day1G3F1', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G3F1', 'VirtualFall2021Day1G3F1']
#
# 20211216
# sub: ['11_21_0_3269', '11_21_0_32', '11_21_0_3269', '11_21_0_3269']
# task: ['DigitSpan', 'RapidObjectNaming', 'DigitSpan', 'GrowthMindsetQuestion']
# item: ['DGS_0_0036_a_U', 'RAO_9002_V_Practice', 'DGS_0_0029_a_U', 'GMS_9001_a_Mindset']
# grade: ['VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2']
#
# 20211111
# sub: ['11_21_0_3152', '11_21_0_3127', '11_21_0_3132', '11_21']
# task: ['SentenceRepetition', 'Synonyms', 'PictureNaming', 'LetterNamingContextDirections2Fall20']
# item: ['SRT_33_package_012', 'SYN_0121_a_repair', 'EVO_9002_a_Directions2', 'LNC_9003_a_Directions2']
# grade: ['VirtualFall2021Day1G3F1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day2KF1']
#
# 20211019
# sub: ['11_21_0_3041', '66_21_0_3059', '11_20_0_2300', '11_21_0_3041']
# task: ['PictureNaming', 'NonwordReading', 'WordReading', 'PictureNaming']
# item: ['EVO_13_chimney_012', 'NRE_0142_a_tobe', 'WRE_9001_p_the', 'EVO_0312_a_owl']
# grade: ['VirtualFall2021Day1KF1', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G2F2', 'VirtualFall2021Day1KF1']
#
# 20211109
# sub: ['66_20_0_2050', '66_20_0_2102', '66_20_0_2102', '66_20_0_2050']
# task: ['PictureNaming', 'PictureNaming', 'Synonyms', 'WordReading']
# item: ['EVO_9003_a_Practice1', 'EVO_9003_b_Practice2', 'SYN_0178_a_request', 'WRE_9002_p_go']
# grade: ['VirtualFall2021Day2G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day2G1F2']
#
# 20211105
# sub: ['66_20_0_2077', '66_20_0_2098', '66_21_0_3035', '66_20_0_2045']
# task: ['PictureNaming', 'DigitSpan', 'NonwordReading', 'NonwordReading']
# item: ['EVO_9002_a_Directions2', 'DGS_0_0032_a_U', 'NRE_49_lut_01', 'NRE_9003_p_vat']
# grade: ['VirtualFall2021Day2G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2']
#
# 20211116
# sub: ['11_21_0_3174', '11_21_0_3044', '11_21_0_316', '11_20_0_2418']
# task: ['PictureNaming', 'Synonyms', 'SentenceRepetition', 'Synonyms']
# item: ['EVO_9003_a_Practice1', 'SYN_6_naughty_012', 'SRT_0140_a_bookhelp', 'SYN_0181_a_punch']
# grade: ['VirtualFall2021Day1KF1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day1G1F2']
#
# 20211006
# sub: ['66_21_0_3141', 'fcrr9', '66_21_0_3065', '66_21_0_3067']
# task: ['PictureNaming', 'RapidObjectNamingDirections2Virtual', 'PictureNaming', 'PictureNaming']
# item: ['EVO_18_parachute_0123', 'RAO_9005_V_Directions4', 'EVO_0295_a_snowman', 'EVO_9002_a_Directions2']
# grade: ['VirtualFall2021Day1KF1', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1KF1', 'VirtualFall2021Day1KF1']
#
# 20211029
# sub: ['66_19_0_1202', '11_20_0_2263', '11_20_0_2039', '11_20_0_2039']
# task: ['SentenceRepetition', 'PictureNaming', 'NonwordReading', 'NonwordReading']
# item: ['SRT_29_visit_1', 'EVO_9002_a_Directions2', 'NRE_33_chisp_123', 'NRE_93_stad_12']
# grade: ['VirtualFall2021Day1G2F2', 'VirtualFall2021Day2G1F2', 'VirtualFall2021Day2G2F2', 'VirtualFall2021Day2G2F2']
#
# 20211213
# sub: ['11_21_0_3', '11_21_0_3224', '11_21_0_3224', '11_21_0_3224']
# task: ['SentenceRepetition', 'SentenceRepetition', 'NonwordReading', 'NonwordReading']
# item: ['SRT_0238_a_driedbowls', 'SRT_0236_a_cakeTV', 'NRE_0197_a_shrent', 'NRE_33_chisp_123']
# grade: ['VirtualFall2021Day2G3F1', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day2G3F1', 'VirtualFall2021Day2G3F1']
#
# 20211203
# sub: ['66_21_0_3152', '66_21_0_3152', '11_21_0_3130', '66_21_0_3152']
# task: ['Blending', 'Blending', 'NonwordReading', 'LetterNamingContext']
# item: ['BLE_0085_a_eyebrow', 'BLE_0088_a_remember', 'NRE_41_spoog_23', 'RAN_Upper_W']
# grade: ['VirtualFall2021Day2KF1', 'VirtualFall2021Day2KF1', 'VirtualFall2021Day1G3F1', 'VirtualFall2021Day2KF1']

# %% [markdown]
# ## Winter Spring 2022
# Jan 31 June 3

# %%
startdate=20220131
enddate=20220603
foldir='/om/tmp/jsmentch/rer/Scores/'
subind=-2
taskind=1
itemind=-3
gradeind=0
#print_examples(startdate,enddate,foldir)
print_sub_task_item(startdate,enddate,foldir,subind,taskind,itemind,gradeind)
# Out:
# 20220318
# sub: ['11_21_0_3066', '66_21_0_3061', '66_21_0_3301', '66_21_0_3534']
# task: ['NonwordReading', 'SentenceRepetition', 'SetforVariability', 'SentenceRepetition']
# item: ['NRE_9002_p_zuk', 'SRT_0116_a_breakfast', 'SFV_0002_a_scissors', 'SRT_0153_a_brushteeth']
# grade: ['VirtualWinter2022Day1G1F2', 'VirtualWinter2022Day2KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day2KF1']
#
# 20220202
# sub: ['11_21', '11_21', '11_21_0_3188', '11_20_0_2336']
# task: ['SentenceRepetition', 'SentenceRepetition', 'WordReading', 'PictureNaming']
# item: ['SRT_0181_a_sciencelab', 'SRT_0181_a_sciencelab', 'WRE_24_said_01', 'EVO_9003_b_Practice2']
# grade: ['VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G1F1']
#
# 20220317
# sub: ['xjx', '66_21_0_3283', '66_21_0_3345', '66_21_0_3534']
# task: ['EVT', 'Synonyms', 'Synonyms', 'NonwordRepetition']
# item: ['EVT_3_0077_camel', 'SYN_25_pony_0', 'SYN_0122_a_kids', 'NWR_0126_kefnuhvohkmerforb']
# grade: ['EndofYearAssessmentG2G3', 'VirtualWinter2022Day2KF2', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1']
#
# 20220421
# sub: ['55_21_0_3037', '11_21_0_3702', '11_21_0_3599', '11_20_0_2561']
# task: ['EVT', 'NonwordRepetition', '', 'EVT']
# item: ['EVT_3_0127_soap', 'NWR_10_kuhcheyvap_012', 'KTEA_LWR_A_items52to57', 'EVT_3_B_rock']
# grade: ['EndofYearAssessmentG2G3', 'VirtualWinter2022Day2G1F1', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3']
#
# 20220307
# sub: ['11_20_0_2006', '11_21_0_3112', '11_21_0_3112', '11_21_0_3132']
# task: ['GrowthMindsetQuestion', 'NonwordRepetition', 'PictureNaming', 'VisualAttention']
# item: ['GMS_9001_a_Mindset', 'NWR_10_kuhcheyvap_012', 'EVO_9002_a_Directions2', 'VAT_0_9001_c_D_v2']
# grade: ['VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day2G3F1']
#
# 20220407
# sub: ['11_21_0_3723', '11_21_0_3723', '11_21_0_3723', '11_21_0_3653']
# task: ['NonwordRepetition', 'NonwordRepetition', 'NonwordReading', 'DigitSpan']
# item: ['NWR_0156_mohgheedoovnoim', 'NWR_10_kuhcheyvap_012', 'NRE_9004_p_dit', 'DGS_3_4837_0']
# grade: ['VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day2KF1']
#
# 20220304
# sub: ['11_20_0_2383', '11_20_0_2001', '66_20_0_2002', '66_19_0_1241']
# task: ['Synonyms', 'Synonyms', 'NonwordReading', 'SentenceRepetition']
# item: ['SYN_75_dad_01', 'SYN_0147_a_exhausted', 'NRE_9004_p_dit', 'SRT_0129_a_guitar']
# grade: ['VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1']
#
# 20220425
# sub: ['66_21_0_3069', '66_20_0_2055', '11_21_0_3067', '11_21_0_3728']
# task: ['', 'WPPSIPN', 'WPPSIPN', '']
# item: ['KTEA_LWR_A_22_on_K1', 'WPPSI_PN_S1_02_bear', 'WPPSI_PN_S1_21_thermometer', 'KTEA_LWR_A_22_on_G23']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3']
#
# 20220502
# sub: ['55_21_0_3077', '11_21_0_3256', '66_21_0_3061', '66_21_0_3062']
# task: ['SetforVariability', 'EVT', 'NonwordReading', 'SentenceRepetition']
# item: ['SFV_0005_a_mechanic', 'EVT_3_0112_missing', 'NRE_0214_a_vop', 'SRT_0149_a_afternoon']
# grade: ['VirtualWinter2022Day1KF1', 'EndofYearAssessmentG2G3', 'VirtualWinter2022Day2KF1', 'VirtualWinter2022Day2KF1']
#
# 20220209
# sub: ['66_21_0_3037', '11_21_0_3211', '11_21_0_3033', '11_21_0_3033']
# task: ['Synonyms', 'Synonyms', 'PictureNaming', 'DigitSpan']
# item: ['SYN_75_dad_01', 'SYN_0166_a_antique', 'EVO_18_parachute_0123', 'DGS_1_1379_0']
# grade: ['VirtualFall2021Day1G1F2', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2KF1', 'VirtualWinter2022Day2KF1']
#
# 20220328
# sub: ['11_21_0_3534', '11_21_0_3247', '11_21_0_3180', '11_21_0_3634']
# task: ['WordReading', 'WordReading', 'VisualAttention', 'Synonyms']
# item: ['WRE_9002_p_go', 'WRE_0286_a_height', 'VAT_0_9001_c_D_v2', 'SYN_20_lady_02']
# grade: ['VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day2G3F1', 'VirtualWinter2022Day2G3F1', 'VirtualWinter2022Day2G2F1']
#
# 20220215
# sub: ['11_20_0_2300', '11_21_0_3313', '11_21_0_3319', '11_21_']
# task: ['PictureNaming', 'WordReading', 'WordReading', 'SentenceRepetition']
# item: ['EVO_9002_a_Directions2', 'WRE_0288_a_tough', 'WRE_9002_p_go', 'SRT_0126_a_libraries']
# grade: ['VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day2G3F1', 'VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1G3F1']
#
# 20220509
# sub: ['66_21_0_3115', '66_21_0_3128', '55_21_0_3093', '66_21_0_3151']
# task: ['WPPSIPN', '', 'NonwordRepetition', 'WPPSIPN']
# item: ['WPPSI_PN_S1_03_banana', 'KTEA_LWR_A_items28to33', 'NWR_11_vugoobuhcheen_012', 'WPPSI_PN_S1_01_car']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'VirtualWinter2022Day1KF1', 'EndofYearAssessmentG1K']
#
# 20220411
# sub: ['55_21_0_3026', '11_21_0_3293', '66_21_0_3288', '11_21_0_3529']
# task: ['WPPSIPN', 'EVT', '', '']
# item: ['WPPSI_PN_S1_07_scissors', 'EVT_3_0085_big', 'KTEA_NWD_A_06_pem', 'KTEA_NWD_A_06_pem']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K']
#
# 20220220
# sub: ['fcrr9013', 'fcrr9013', 'fcrr9013', 'fcrr9013']
# task: ['NonwordReading', 'NonwordReading', 'NonwordReading', 'Synonyms']
# item: ['NRE_9003_p_vat', 'NRE_9002_p_zuk', 'NRE_0107_a_fep', 'SYN_75_dad_01']
# grade: ['VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2', 'VirtualFall2021Day1G1F2']
#
# 20220331
# sub: ['xmx', 'xfx', '11_21_0_3061', '11_21_0_3560']
# task: ['WPPSIPN', '', 'WordReading', 'NonwordReading']
# item: ['WPPSI_PN_S1_06_clock', 'KTEA_LWR_A_21_R', 'WRE_9001_b_D', 'NRE_0241_a_barm']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G3F1']
#
# 20220303
# sub: ['66_21_', '66_21_0_3253', '66_20_0_2199', '66_21_0_3253']
# task: ['NonwordRepetition', 'SetforVariability', 'SentenceRepetition', 'SetforVariability']
# item: ['NWR_0125_kahybeymookdowb', 'SFV_0001_a_muscles', 'SRT_12_tired_0L', 'SFV_0006_a_banana']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day2KF1', 'VirtualWinter2022Day1KF1']
#
# 20220404
# sub: ['11_21_0_3643', '11_21_0_3660', '11_21_0_3674', '11_21_0_3678']
# task: ['SetforVariability', 'SetforVariability', 'Synonyms', 'SetforVariability']
# item: ['SFV_0001_a_muscles', 'SFV_0009_a_was', 'SYN_34_unhappy_0', 'SFV_0011_a_is']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1']
#
# 20220505
# sub: ['66_21_0_3261', '11_20_0_2247', '11_21_0_3747', '66_19_0_1065']
# task: ['SentenceRepetition', 'EVT', '', 'WordReading']
# item: ['SRT_12_tired_0L', 'EVT_3_0075_shut', 'KTEA_LWR_A_items34to39', 'WRE_9002_p_go']
# grade: ['VirtualFall2021Day1KF1', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'VirtualWinter2022Day2G2F1']
#
# 20220422
# sub: ['11_21_0_3564', '11_20_0_2383', '11_21_0_3528', '11_20_0_2383']
# task: ['EVT', 'EVT', '', '']
# item: ['EVT_3_0106_talk', 'EVT_3_0078_donkey', 'KTEA_LWR_A_20_N', 'KTEA_NWD_A_item07to12']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3']
#
# 20220329
# sub: ['xfx', 'xfx', 'xfx', 'xfx']
# task: ['EVT', 'EVT', 'EVT', 'EVT']
# item: ['EVT_3_0079_parrot', 'EVT_3_0081_pear', 'EVT_3_0075_shut', 'EVT_3_A_singing']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3']
#
# 20220527
# sub: ['66_19_0_1168', '66_20_0_2206', '66_21_0_3225', '66_19_0_1196']
# task: ['', 'WPPSIPN', 'WPPSIPN', 'EVT']
# item: ['KTEA_LWR_A_items34to39', 'WPPSI_PN_S1_05_star', 'WPPSI_PN_S1_17_nail', 'EVT_3_0079_parrot']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3']
#
# 20220429
# sub: ['11_21_0_3179', '11_21_0_3107', '66_20_0_2056', '66_19_0_1162']
# task: ['EVT', 'EVT', 'WPPSIPN', 'EVT']
# item: ['EVT_3_0078_donkey', 'EVT_3_0086_judge', 'WPPSI_PN_S1_12_shell', 'EVT_3_0079_parrot']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3']
#
# 20220302
# sub: ['66_21_0_3155', '66_21_0_3', '1', '66_21_0_315']
# task: ['WordReading', 'NonwordRepetition', 'NonwordRepetition', 'SentenceRepetition']
# item: ['WRE_9001_p_the', 'NWR_0124_toovhohgneeb', 'NWR_12_goomdachahytowb_012', 'SRT_0242_a_pudding']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1KF2']
#
# 20220526
# sub: ['55_21_0_3060', '55_21_0_3073', '55_21_0_3057', '55_21_0_3106']
# task: ['WPPSIPN', '', 'WPPSIPN', 'Synonyms']
# item: ['WPPSI_PN_S1_11_kangaroo', 'KTEA_NWD_A_04_hapt', 'WPPSI_PN_S1_22_harp', 'SYN_0166_a_antique']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'VirtualWinter2022Day2G1F1']
#
# 20220512
# sub: ['55_21_0_3067', '55_21_0_3063', '55_21_0_3067', '55_21_0_3064']
# task: ['SetforVariability', 'SetforVariability', 'Synonyms', 'NonwordRepetition']
# item: ['SFV_0012_a_breakfast', 'SFV_0012_a_breakfast', 'SYN_0127_a_automobile', 'NWR_10_kuhcheyvap_012']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1']
#
# 20220403
# sub: ['xlx', 'xlx', 'xlx', 'xlx']
# task: ['', 'EVT', 'PearsonCopyright', 'PearsonCopyright']
# item: ['KTEA_LWR_A_22_on_G23', 'EVT_3_B_rock', 'pearson_copyright_EVT', 'LWD']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3']
#
# 20220330
# sub: ['xfx', 'xfx', 'xfx', '11_21_0_3066']
# task: ['WPPSIPN', '', 'WPPSIPN', 'NonwordReading']
# item: ['WPPSI_PN_S1_03_banana', 'KTEA_LWR_A_18_T', 'WPPSI_PN_S1_05_star', 'NRE_9004_p_dit']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'VirtualWinter2022Day2G1F2']
#
# 20220204
# sub: ['11_21_0_3', '11_21_0_3077', '11_21_0_3069', '11_21_0_3053']
# task: ['NonwordRepetition', 'WordReading', 'WordReading', 'GrowthMindsetQuestion']
# item: ['NWR_10_kuhcheyvap_012', 'WRE_9001_b_D', 'WRE_14_inside_012', 'GMS_9001_a_Mindset']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day1G1F1']
#
# 20220420
# sub: ['11_20_0_2039', '11_20_0_2039', '11_21_0_3567', '11_21_0_3122']
# task: ['', 'EVT', 'Synonyms', '']
# item: ['KTEA_LWR_A_items34to39', 'EVT_3_0090_rectangle', 'SYN_0145_a_furious', 'KTEA_LWR_A_items28to33']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'VirtualWinter2022Day2G2F1', 'EndofYearAssessmentG2G3']
#
# 20220518
# sub: ['66_19_0_1036', '66_19_0_1152', '66_20_0_2100', '66_20_0_2050']
# task: ['EVT', 'EVT', 'WPPSIPN', '']
# item: ['EVT_3_0102_verypretty', 'EVT_3_0119_vision', 'WPPSI_PN_S1_21_thermometer', 'KTEA_NWD_A_02_vip']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K']
#
# 20220415
# sub: ['11_21_0_3316', '11_21_0_3146', '11_21_0_3759', '11_21_0_3172']
# task: ['EVT', 'EVT', 'Synonyms', 'EVT']
# item: ['EVT_3_0105_below', 'EVT_3_0124_hoof', 'SYN_75_dad_01', 'EVT_3_0108_peacock']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'VirtualWinter2022Day2G2F1', 'EndofYearAssessmentG2G3']
#
# 20220315
# sub: ['66_21_0_3364', '11_21_0_3573', '66_21_0_3350', '66_21_0_3350']
# task: ['NonwordReading', 'WordReading', 'SetforVariability', 'Synonyms']
# item: ['NRE_9003_p_vat', 'WRE_9001_p_the', 'SFV_0012_a_breakfast', 'SYN_0123_a_leave']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1']
#
# 20220321
# sub: ['11_20_0_2209', '66_21_0_3347', '66_21_0_3299', '66_21_0_3291']
# task: ['SentenceRepetition', 'SentenceRepetition', 'Synonyms', 'NonwordReading']
# item: ['SRT_0233_a_neverboring', 'SRT_9_willie_012L', 'SYN_34_unhappy_0', 'NRE_9002_p_zuk']
# grade: ['VirtualWinter2022Day1G3F1', 'VirtualWinter2022Day2KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day2KF1']
#
# 20220519
# sub: ['xrx', '11_20_0_2348', 'xpx', '11_20_0_2348']
# task: ['', 'EVT', 'WPPSIPN', 'PearsonCopyright']
# item: ['KTEA_NWD_A_01_af', 'EVT_3_0082_astronaut', 'WPPSI_PN_S1_10_guitar', 'NWD']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3']
#
# 20220211
# sub: ['11_21_0_3005', '55_21_0_3020', '55_21_0_3025', '55_21_0_30']
# task: ['NonwordReading', 'Synonyms', 'Synonyms', 'SentenceRepetition']
# item: ['NRE_9002_p_zuk', 'SYN_0148_a_finish', 'SYN_0166_a_antique', 'SRT_0145_a_colorful']
# grade: ['VirtualWinter2022Day2KF1', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2KF1']
#
# 20220222
# sub: ['11_21_0_3179', '11_21_0_3093', '11_21_0_3110', '55_21_0_']
# task: ['Synonyms', 'PictureNaming', 'WordReading', 'SentenceRepetition']
# item: ['SYN_0199_a_equivalent', 'EVO_9003_b_Practice2', 'WRE_9002_p_go', 'SRT_0169_a_bigcake']
# grade: ['VirtualWinter2022Day1G3F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1']
#
# 20220418
# sub: ['11_21_0_3747', '11_21_0_3600', '11_21_0_3684', '11_21_0_3145']
# task: ['NonwordRepetition', 'EVT', 'SentenceRepetition', '']
# item: ['NWR_12_goomdachahytowb_012', 'EVT_3_0102_verypretty', 'SRT_0190_a_dance', 'KTEA_NWD_A_06_pem']
# grade: ['VirtualWinter2022Day2G1F1', 'EndofYearAssessmentG2G3', 'VirtualWinter2022Day1G1F1', 'EndofYearAssessmentG2G3']
#
# 20220413
# sub: ['11_21_0_3079', '66_21_0_3300', '11_21_0_3126', '11_20_0_2147']
# task: ['WPPSIPN', '', 'EVT', 'WPPSIPN']
# item: ['WPPSI_PN_S1_20_xylophone', 'KTEA_NWD_A_05_mab', 'EVT_3_0128_funnel', 'WPPSI_PN_S1_05_star']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K']
#
# 20220227
# sub: ['fcrr9002', 'fcrr9002', 'fcrr9002', 'fcrr9002']
# task: ['NonwordRepetition', 'PairedAssociatesLearning', 'Deletion', 'NonwordRepetition']
# item: ['NWR_0122_geemtohf', 'PAL_0_S_0001_a_U_Teeg', 'DEL_9003_p_baseball1', 'NWR_0082_moid']
# grade: ['Fall2021Day1KF2', 'Fall2021Day1KF2', 'Fall2021Day1KF2', 'Fall2021Day1KF2']
#
# 20220506
# sub: ['55_21_0_3108', '66_21_0_3207', '55_21_0_3107', '66_20_0_2168']
# task: ['NonwordRepetition', 'Synonyms', 'Synonyms', 'NonwordRepetition']
# item: ['NWR_0164_goifpahyd', 'SYN_6_naughty_012', 'SYN_0167_a_fearful', 'NWR_0139_deevmeygpohf']
# grade: ['VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G1F1']
#
# 20220324
# sub: ['11_21_0_3577', '11_21_0_3577', '11_21_0_3600', '11_21_0_3600']
# task: ['WordReading', 'WordReading', 'NonwordRepetition', 'WordReading']
# item: ['WRE_0135_a_follow', 'WRE_5_both_0123', 'NWR_12_goomdachahytowb_012', 'WRE_9001_b_D']
# grade: ['VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1']
#
# 20220217
# sub: ['11_21_0_3148', '11_2', '11_20_0_25', '']
# task: ['WordReading', 'SentenceRepetition', 'NonwordRepetition', 'NonwordRepetition']
# item: ['WRE_0289_a_opinion', 'SRT_0176_a_darkoutside', 'NWR_0158_nohftowb', 'NWR_0157_forbmuhteevheynohg']
# grade: ['VirtualWinter2022Day2G3F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1']
#
# 20220517
# sub: ['55_21_0_3104', '55_21_0_3065', '55_21_0_3103', '55_21_0_3114']
# task: ['NonwordRepetition', 'SentenceRepetition', 'Synonyms', 'NonwordRepetition']
# item: ['NWR_10_kuhcheyvap_012', 'SRT_0153_a_brushteeth', 'SYN_0176_a_receive', 'NWR_12_goomdachahytowb_012']
# grade: ['VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2KF1', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G1F1']
#
# 20220602
# sub: ['55_21_0_3092', '55_21_0_3092', '55_21_0_3117', '55_21_0_3109']
# task: ['', 'WPPSIPN', '', 'WPPSIPN']
# item: ['KTEA_LWR_A_18_T', 'WPPSI_PN_S1_18_teapot', 'KTEA_LWR_A_20_N', 'WPPSI_PN_S1_09_ladybug']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K']
#
# 20220131
# sub: ['11_21_0_30', '11_21_0_3037', '11_21_0_3079', '11_21_0_3039']
# task: ['SentenceRepetition', 'Synonyms', 'WordReading', 'NonwordRepetition']
# item: ['SRT_6_quiet_012L', 'SYN_0123_a_leave', 'WRE_0135_a_follow', 'NWR_0087_gahyfmowb']
# grade: ['VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1KF1']
#
# 20220406
# sub: ['11_21_0_3677', '11_21_0_3665', '11_21_0_3558', '11_21_0_3680']
# task: ['DigitSpan', 'PictureNaming', 'WordReading', 'DigitSpan']
# item: ['DGS_2_7528_0', 'EVO_9003_b_Practice2', 'WRE_9002_p_go', 'DGS_4_2759_0']
# grade: ['VirtualWinter2022Day2KF1', 'VirtualWinter2022Day2KF1', 'VirtualWinter2022Day2G3F1', 'VirtualWinter2022Day2KF1']
#
# 20220427
# sub: ['11_21_0_3682', '11_21_0_3005', '11_21_0_3671', '11_21_0_3672']
# task: ['WPPSIPN', 'WPPSIPN', '', '']
# item: ['WPPSI_PN_S1_12_shell', 'WPPSI_PN_S1_07_scissors', 'KTEA_NWD_A_04_hapt', 'KTEA_NWD_A_05_mab']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K']
#
# 20220523
# sub: ['55_21_0_3084', '66_19_0_1172', '55_21_0_3079', '66_21_0_3029']
# task: ['WPPSIPN', 'EVT', '', '']
# item: ['WPPSI_PN_S1_21_thermometer', 'EVT_3_0095_dozen', 'KTEA_NWD_A_04_hapt', 'KTEA_NWD_A_06_pem']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3']
#
# 20220510
# sub: ['55_21_0_3069', '55_21_0_3055', '55_21_0_3060', '55_21_0_3056']
# task: ['SetforVariability', 'NonwordRepetition', 'NonwordReading', 'NonwordRepetition']
# item: ['SFV_0009_a_was', 'NWR_0087_gahyfmowb', 'NRE_9002_p_zuk', 'NWR_11_vugoobuhcheen_012']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1']
#
# 20220419
# sub: ['11_20_0_2300', '11_21_0_3576', '11_21_0_3709', '11_21_0_3699']
# task: ['EVT', 'WPPSIPN', 'NonwordReading', 'SentenceRepetition']
# item: ['EVT_3_0088_fruit', 'WPPSI_PN_S1_18_teapot', 'NRE_0103_a_cheg', 'SRT_0195_a_fiveyellow']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1G1F1']
#
# 20220323
# sub: ['11_20_0_2209', 'xix', 'xix', '11_20_0_2209']
# task: ['WordReading', 'EVT', 'EVT', 'VisualAttention']
# item: ['WRE_9001_b_D', 'EVT_3_0116_money', 'EVT_3_0097_pyramids', 'VAT_0_9001_a_D_v2']
# grade: ['VirtualWinter2022Day2G3F1', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'VirtualWinter2022Day2G3F1']
#
# 20220216
# sub: ['x26x', '66_20_0_2174', '11_21_', '66_20_0_2174']
# task: ['NonwordRepetition', 'PictureNaming', 'SentenceRepetition', 'NonwordReading']
# item: ['NWR_0140_geftohgneeb', 'EVO_9002_a_Directions2', 'SRT_0235_a_catchworm', 'NRE_0122_a_lanfick']
# grade: ['VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1G3F1', 'VirtualWinter2022Day1G1F1']
#
# 20220513
# sub: ['11_20_0_2006', '55_21_0_3087', '55_21_0_3065', '55_21_0_3083']
# task: ['EVT', 'PictureNaming', 'NonwordRepetition', 'DigitSpan']
# item: ['EVT_3_0109_thorns', 'EVO_9002_a_Directions2', 'NWR_0106_vergowfduhboik', 'DGS_R_9274_0']
# grade: ['EndofYearAssessmentG2G3', 'VirtualWinter2022Day2KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day2KF1']
#
# 20220410
# sub: ['xlx', 'xlx', 'xlx', 'xlx']
# task: ['', 'EVT', 'EVT', 'PearsonCopyright']
# item: ['KTEA_LWR_A_22_on_G23', 'EVT_3_A_singing', 'EVT_3_B_rock', 'pearson_copyright_EVT']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3']
#
# 20220426
# sub: ['66_21_0_3077', '66_19_0_1268', '66_20_0_2088', '11_20_0_2209']
# task: ['WPPSIPN', 'WPPSIPN', 'WPPSIPN', 'EVT']
# item: ['WPPSI_PN_S1_02_bear', 'WPPSI_PN_S1_21_thermometer', 'WPPSI_PN_S1_19_globe', 'EVT_3_0108_peacock']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3']
#
# 20220327
# sub: ['xlx', 'xlx', 'xkx', 'xlx']
# task: ['', 'WPPSIPN', '', 'WPPSIPN']
# item: ['KTEA_LWR_A_items34to39', 'WPPSI_PN_S1_03_banana', 'KTEA_LWR_A_items76to81', 'WPPSI_PN_S1_05_star']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K']
#
# 20220214
# sub: ['66_21_0_32', '11_21_0_3160', '66_20_0_2149', '11_21_0_3109']
# task: ['SentenceRepetition', 'Synonyms', 'WordReading', 'PictureNaming']
# item: ['SRT_0127_a_nurse', 'SYN_0189_a_harm', 'WRE_0161_a_sound', 'EVO_17_paddle_012']
# grade: ['VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1G3F1', 'VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1G2F1']
#
# 20220309
# sub: ['11_20_0_2140', '11_21_0_3527', '11_20_0_2162', '11_21_0_3180']
# task: ['WordReading', 'WordReading', 'SentenceRepetition', 'Synonyms']
# item: ['WRE_9002_p_go', 'WRE_64_had_01', 'SRT_0199_a_apples', 'SYN_0034_a_perspire']
# grade: ['VirtualWinter2022Day1G1F2', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G1F2', 'VirtualWinter2022Day1G3F1']
#
# 20220316
# sub: ['11_20_0_2171', '11_21_0_3614', '11_21_0_3614', '11_21_0_3614']
# task: ['WordReading', 'NonwordReading', 'NonwordRepetition', 'WordReading']
# item: ['WRE_9001_b_D', 'NRE_0206_a_tus', 'NWR_0123_meevteyfohg', 'WRE_66_five_0']
# grade: ['VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1']
#
# 20220301
# sub: ['6', '11_21_0_3054', '11_21_0_3122', '11_20_0_252']
# task: ['NonwordRepetition', 'Synonyms', 'Synonyms', 'VisualAttention']
# item: ['NWR_12_goomdachahytowb_012', 'SYN_0169_a_celebration', 'SYN_20_lady_02', 'VAT_0_9001_c_D_v2']
# grade: ['VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day2G2F1']
#
# 20220314
# sub: ['11_20_0_2304', '66_21_0_3535', '66_21_0_3537', '66_21_0_3531']
# task: ['Synonyms', 'Synonyms', 'WordReading', 'SetforVariability']
# item: ['SYN_0189_a_harm', 'SYN_0123_a_leave', 'WRE_24_said_01', 'SFV_0003_a_castle']
# grade: ['VirtualWinter2022Day1G3F1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1']
#
# 20220531
# sub: ['55_21_0_3104', '55_21_0_3104', '55_21_0_3102', '55_21_0_3103']
# task: ['', '', '', 'WPPSIPN']
# item: ['KTEA_LWR_A_22_on_K1', 'KTEA_LWR_A_19_F', 'KTEA_LWR_A_items40to45', 'WPPSI_PN_S1_21_thermometer']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K']
#
# 20220221
# sub: ['11_21_0_3334', '11_21_0_3313', '11_2', '11_21_0_3313']
# task: ['Synonyms', 'Synonyms', 'NonwordRepetition', 'WordReading']
# item: ['SYN_0132_a_thief', 'SYN_0155_a_anxious', 'NWR_12_goomdachahytowb_012', 'WRE_0286_a_height']
# grade: ['VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day1G3F1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day2G3F1']
#
# 20220210
# sub: ['55_19_0_1049', '55_21_0_3004', '66_20_0_2211', '55_19_0_1049']
# task: ['NonwordReading', 'NonwordReading', 'Synonyms', 'WordReading']
# item: ['NRE_0229_a_freg', 'NRE_6_pate_012', 'SYN_62_silent_01', 'WRE_0239_a_custom']
# grade: ['VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day2KF1', 'VirtualFall2021Day1G1F2', 'VirtualWinter2022Day2G2F1']
#
# 20220223
# sub: ['11_21_0_3169', '11_20', '66_20_0_2109', '66_20_']
# task: ['NonwordReading', 'SentenceRepetition', 'PictureNaming', 'SentenceRepetition']
# item: ['NRE_9004_p_dit', 'SRT_0229_a_happydance', 'EVO_9002_a_Directions2', 'SRT_0182_a_bellrings']
# grade: ['VirtualWinter2022Day2KF1', 'VirtualWinter2022Day1G3F1', 'VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1G1F1']
#
# 20220325
# sub: ['xfx', '66_21_0_3447', 'xkx', '66_19_0_1267']
# task: ['', 'PictureNaming', 'EVT', 'SentenceRepetition']
# item: ['KTEA_LWR_A_17_K', 'EVO_69_collar_123', 'EVT_3_B_rock', 'SRT_0173_a_babypigs']
# grade: ['EndofYearAssessmentG1K', 'VirtualWinter2022Day1G2F1', 'EndofYearAssessmentG2G3', 'VirtualWinter2022Day1G2F1']
#
# 20220308
# sub: ['11_21_0_3527', '11_21_0_3112', '66_21_0_3069', '11_21_0_3527']
# task: ['SentenceRepetition', 'Synonyms', 'NonwordRepetition', 'VisualAttention']
# item: ['SRT_93_boyshome_0', 'SYN_0143_a_sprint', 'NWR_0124_toovhohgneeb', 'VAT_0_9001_a_D_v2']
# grade: ['VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G1F1']
#
# 20220218
# sub: ['11_20_0', '11_20_0_2', '11_20_0_', '11_21_0_3146']
# task: ['SentenceRepetition', 'SentenceRepetition', 'SentenceRepetition', 'NonwordReading']
# item: ['SRT_0207_a_readbook', 'SRT_0129_a_guitar', 'SRT_33_package_012', 'NRE_9003_p_vat']
# grade: ['VirtualWinter2022Day1G3F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G3F1']
#
# 20220203
# sub: ['11_20_0_2218', '11_21_0_3174', '11_21_0_3319', '11_21_0_']
# task: ['WordReading', 'Synonyms', 'PictureNaming', 'SentenceRepetition']
# item: ['WRE_9001_b_D', 'SYN_0123_a_leave', 'EVO_0390_a_panda', 'SRT_0191_a_turtles']
# grade: ['VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1G1F1']
#
# 20220525
# sub: ['66_21_0_3000', '66_19_0_1181', '66_21_0_3277', '66_21_0_3113']
# task: ['', 'EVT', 'WPPSIPN', 'EVT']
# item: ['KTEA_NWD_A_03_ko', 'EVT_3_0088_fruit', 'WPPSI_PN_S1_08_toothbrush', 'EVT_3_0127_soap']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3']
#
# 20220224
# sub: ['11_21_0_3113', '66_21_0_3137', '66_20_0_2098', '11_21_0_3082']
# task: ['Synonyms', 'GrowthMindsetQuestion', 'Synonyms', 'NonwordReading']
# item: ['SYN_0143_a_sprint', 'GMS_9001_a_Mindset', 'SYN_0148_a_finish', 'NRE_9004_p_dit']
# grade: ['VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G2F1']
#
# 20220311
# sub: ['11_21_0_3552', '11_21_0_3019', '11_21_0_3528', '11_21_0_3552']
# task: ['NonwordReading', 'SentenceRepetition', 'SetforVariability', 'SentenceRepetition']
# item: ['NRE_43_skamply_23', 'SRT_0252_a_takepictures', 'SFV_9003_a_Practice2', 'SRT_0234_a_downloaded']
# grade: ['VirtualWinter2022Day1G3F1', 'VirtualWinter2022Day1KF2', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G3F1']
#
# 20220516
# sub: ['66_21_0_3067', '55_21_0_3056', '66_21_0_3190', '66_21_0_3271']
# task: ['WPPSIPN', 'SentenceRepetition', 'WPPSIPN', '']
# item: ['WPPSI_PN_S1_11_kangaroo', 'SRT_0154_a_bake', 'WPPSI_PN_S1_01_car', 'KTEA_NWD_A_04_hapt']
# grade: ['EndofYearAssessmentG1K', 'VirtualWinter2022Day2KF1', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K']
#
# 20220524
# sub: ['55_21_0_3072', '55_21_0_3083', '55_21_0_3083', '55_21_0_3083']
# task: ['', 'WPPSIPN', 'WPPSIPN', '']
# item: ['KTEA_NWD_A_03_ko', 'WPPSI_PN_S1_05_star', 'WPPSI_PN_S1_22_harp', 'KTEA_NWD_A_item07to12']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K']
#
# 20220208
# sub: ['55_21_0_3002', '55_21_0_3002', '55_21_0_3041', '66_20_0_2200']
# task: ['NonwordRepetition', 'SetforVariability', 'SetforVariability', 'RapidObjectNaming']
# item: ['NWR_0087_gahyfmowb', 'SFV_0007_a_have', 'SFV_0006_a_banana', 'RAO_0002_a_book']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualFall2021Day1G1F2']
#
# 20220401
# sub: ['11_21_0_3563', 'xfx', '11_21_0_3564', 'xfx']
# task: ['Synonyms', 'WPPSIPN', 'SentenceRepetition', 'WPPSIPN']
# item: ['SYN_75_dad_01', 'WPPSI_PN_S1_10_guitar', 'SRT_0229_a_happydance', 'WPPSI_PN_S1_05_star']
# grade: ['VirtualWinter2022Day2G1F1', 'EndofYearAssessmentG1K', 'VirtualWinter2022Day1G3F1', 'EndofYearAssessmentG1K']
#
# 20220414
# sub: ['66_20_0_2102', '11_21_0_3174', '66_20_0_2180', '55_21_0_3010']
# task: ['', 'WPPSIPN', '', '']
# item: ['KTEA_LWR_A_18_T', 'WPPSI_PN_S1_20_xylophone', 'KTEA_NWD_A_04_hapt', 'KTEA_LWR_A_18_T']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K']
#
# 20220408
# sub: ['xfx', 'xfx', 'xfx', 'xfx']
# task: ['', '', '', '']
# item: ['KTEA_NWD_A_item37to42', 'KTEA_NWD_A_06_pem', 'KTEA_NWD_A_03_ko', 'KTEA_NWD_A_05_mab']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3']
#
# 20220228
# sub: ['66_', '11_21_0_3093', '66_20_0_2048', '66_20_0_2048']
# task: ['NonwordRepetition', 'Synonyms', 'Synonyms', 'Synonyms']
# item: ['NWR_0144_bowmhoideegmohf', 'SYN_52_applaud_2', 'SYN_0167_a_fearful', 'SYN_1_quick_012']
# grade: ['VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G1F1']
#
# 20220428
# sub: ['11_21_0_3197', '11_20_0_2564', '66_21_0_3198', '11_21_0_3180']
# task: ['', '', '', 'EVT']
# item: ['KTEA_LWR_A_21_R', 'KTEA_NWD_A_item31to36', 'KTEA_LWR_A_21_R', 'EVT_3_0107_cruise']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3']
#
# 20220225
# sub: ['66_21_', '11_21_0_3006', '11_20_0_2147', '55_21_0_3037']
# task: ['NonwordRepetition', 'SentenceRepetition', 'Synonyms', 'WordReading']
# item: ['NWR_0125_kahybeymookdowb', 'SRT_50_folder_0', 'SYN_0169_a_celebration', 'WRE_9001_p_the']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF2', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day2G3F1']
#
# 20220405
# sub: ['11_21_0_3670', '11_21_0_3659', '11_21_0_3679', '11_21_0_3653']
# task: ['SentenceRepetition', 'SentenceRepetition', 'Synonyms', 'NonwordRepetition']
# item: ['SRT_0146_a_principal', 'SRT_0146_a_principal', 'SYN_4_hop_0L', 'NWR_0106_vergowfduhboik']
# grade: ['VirtualWinter2022Day2KF1', 'VirtualWinter2022Day2KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1']
#
# 20220310
# sub: ['66_21_0_3288', '11_21_0_3549', '66_21_0_3287', '11_20_0_2282']
# task: ['NonwordReading', 'NonwordReading', 'NonwordRepetition', 'PairedAssociatesLearning']
# item: ['NRE_9003_p_vat', 'NRE_0144_a_tusgid', 'NWR_11_vugoobuhcheen_012', 'PAL_0_S_0002_a_U_Mowgaif']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G1F2']
#
# 20220520
# sub: ['66_19_0_1266', '66_20_0_2002', '66_21_0_3111', '66_19_0_1011']
# task: ['', 'EVT', 'EVT', 'EVT']
# item: ['KTEA_LWR_A_items52to57', 'EVT_3_0097_pyramids', 'EVT_3_0077_camel', 'EVT_3_0089_evening']
# grade: ['EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG2G3']
#
# 20220322
# sub: ['66_19_0_1196', '66_21_0_3002', 'xcx', '66_21_0_3111']
# task: ['WordReading', 'SentenceRepetition', '', 'SentenceRepetition']
# item: ['WRE_9002_p_go', 'SRT_0178_a_icecream', 'KTEA_NWD_A_03_ko', 'SRT_0129_a_guitar']
# grade: ['VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1', 'EndofYearAssessmentG1K', 'VirtualWinter2022Day1G2F1']
#
# 20220511
# sub: ['55_21_0_3088', '55_21_0_3058', '55_21_0_3058', '55_21_0_3061']
# task: ['SetforVariability', 'WordReading', 'SetforVariability', 'WordReading']
# item: ['SFV_0007_a_have', 'WRE_9001_b_D', 'SFV_0009_a_was', 'WRE_9002_p_go']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1']
#
# 20220206
# sub: ['xhx', 'xix', 'xhx', 'xhx']
# task: ['Synonyms', 'WordReading', 'Synonyms', 'VisualAttention']
# item: ['SYN_0147_a_exhausted', 'WRE_0288_a_tough', 'SYN_0143_a_sprint', 'VAT_0_9001_a_D_v2']
# grade: ['VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day2G3F1', 'VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day2G2F1']
#
# 20220412
# sub: ['55_21_0_3002', '11_21_0_3147', '55_21_0_3011', '11_21_0_3653']
# task: ['WPPSIPN', 'EVT', 'WPPSIPN', '']
# item: ['WPPSI_PN_S1_17_nail', 'EVT_3_0090_rectangle', 'WPPSI_PN_S1_13_broom', 'KTEA_NWD_A_06_pem']
# grade: ['EndofYearAssessmentG1K', 'EndofYearAssessmentG2G3', 'EndofYearAssessmentG1K', 'EndofYearAssessmentG1K']
#
# 20220201
# sub: ['11_21_0_3067', '11_20_0_2264', '11_21_0_3067', '11_21_0_32']
# task: ['Synonyms', 'PictureNaming', 'SetforVariability', 'SentenceRepetition']
# item: ['SYN_0127_a_automobile', 'EVO_0391_a_halo', 'SFV_0010_a_school', 'SRT_0127_a_nurse']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G1F1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1G1F1']
#
# 20220503
# sub: ['55_21_0_3082', '55_21_0_3082', '66_19_0_1236', '55_21_0_3072']
# task: ['SentenceRepetition', 'SentenceRepetition', 'WordReading', 'PictureNaming']
# item: ['SRT_0149_a_afternoon', 'SRT_0151_a_crayon', 'WRE_9002_p_go', 'EVO_9003_b_Practice2']
# grade: ['VirtualWinter2022Day2KF1', 'VirtualWinter2022Day2KF1', 'VirtualWinter2022Day2G2F1', 'VirtualWinter2022Day2KF1']
#
# 20220207
# sub: ['55_21_0_3004', '11_20_0_2152', '55_21_0_3031', '55_19_0_1']
# task: ['WordReading', 'WordReading', 'PictureNaming', 'SentenceRepetition']
# item: ['WRE_38_before_01', 'WRE_0211_a_soft', 'EVO_0423_a_pot', 'SRT_9_willie_012L']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day2G1F1', 'VirtualWinter2022Day1G2F1', 'VirtualWinter2022Day1G2F1']
#
# 20220504
# sub: ['55_21_0_3091', '55_21_0_3094', '55_21_0_3075', '11_21_0_3558']
# task: ['NonwordReading', 'SetforVariability', 'DigitSpan', 'EVT']
# item: ['NRE_49_lut_01', 'SFV_0009_a_was', 'DGS_5_5842_0', 'EVT_3_0086_judge']
# grade: ['VirtualWinter2022Day1KF1', 'VirtualWinter2022Day1KF1', 'VirtualWinter2022Day2KF1', 'EndofYearAssessmentG2G3']
